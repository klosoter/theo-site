# %%
#!/usr/bin/env python3
import os, json, pathlib, datetime, shutil
from flask import Flask, jsonify, request, send_from_directory
from dotenv import load_dotenv

load_dotenv()
ROOT = pathlib.Path(".").parent.resolve()
DATA_DIR = pathlib.Path(os.getenv("DATA_DIR", ROOT / "../data")).resolve()

THEO_FILE = DATA_DIR / "theologians.json"
WORKS_FILE = DATA_DIR / "works.json"
MAP_FILE = DATA_DIR / "work_canon_map.json"
AUTHORS_REGISTRY = DATA_DIR / "authors_registry.json"
OUTLINES_JSONL = DATA_DIR / "outlines.jsonl"
BY_WORK = DATA_DIR / "indices/by_work.json"
BY_TOPIC = DATA_DIR / "indices/by_topic.json"
BY_THEO = DATA_DIR / "indices/by_theologian.json"

app = Flask(__name__, static_folder=str(ROOT / "static"))


def _load_json(path: pathlib.Path, default=None):
    try:
        return json.loads(path.read_text(encoding="utf-8"))
    except FileNotFoundError:
        return default


def _write_json(path: pathlib.Path, obj):
    ts = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    if path.exists():
        backups = path.parent / "backups"
        backups.mkdir(parents=True, exist_ok=True)
        shutil.copy2(path, backups / f"{path.name}.bak-{ts}")
    path.write_text(json.dumps(obj, ensure_ascii=False, indent=2), encoding="utf-8")


CACHE = {}


def _reload():
    CACHE["theologians"] = _load_json(THEO_FILE, []) or []
    CACHE["works"] = _load_json(WORKS_FILE, []) or []
    CACHE["canon_map"] = _load_map(CACHE["works"])


def _load_map(all_works):
    rows = _load_json(MAP_FILE, []) or []
    m = {}
    for r in rows:
        wid = r.get("work_id");
        cid = r.get("canonical_id")
        if wid and cid:
            m[wid] = cid
    # ensure all work ids have a mapping (identity)
    for w in (all_works or []):
        wid = w.get("id")
        if wid:
            m.setdefault(wid, wid)
    # compress
    for wid in list(m.keys()):
        m[wid] = _root(m, wid)
    return m


def _save_map(m):
    rows = [{"work_id": wid, "canonical_id": cid} for wid, cid in sorted(m.items())]
    _write_json(MAP_FILE, rows)

# %%
#!/usr/bin/env python3
import os, json, pathlib, datetime, shutil
from flask import Flask, jsonify, request, send_from_directory
from dotenv import load_dotenv

load_dotenv()
ROOT = pathlib.Path(".").parent.resolve()
DATA_DIR = pathlib.Path(os.getenv("DATA_DIR", ROOT / "../data")).resolve()

THEO_FILE = DATA_DIR / "theologians.json"
WORKS_FILE = DATA_DIR / "works.json"
MAP_FILE = DATA_DIR / "work_canon_map.json"

app = Flask(__name__, static_folder=str(ROOT / "static"))


def _load_json(path: pathlib.Path, default=None):
    try:
        return json.loads(path.read_text(encoding="utf-8"))
    except FileNotFoundError:
        return default


def _write_json(path: pathlib.Path, obj):
    ts = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    if path.exists():
        backups = path.parent / "backups"
        backups.mkdir(parents=True, exist_ok=True)
        shutil.copy2(path, backups / f"{path.name}.bak-{ts}")
    path.write_text(json.dumps(obj, ensure_ascii=False, indent=2), encoding="utf-8")


CACHE = {}


def _reload():
    CACHE["theologians"] = _load_json(THEO_FILE, []) or []
    CACHE["works"] = _load_json(WORKS_FILE, []) or []
    CACHE["canon_map"] = _load_map(CACHE["works"])


def _load_map(all_works):
    rows = _load_json(MAP_FILE, []) or []
    m = {}
    for r in rows:
        wid = r.get("work_id");
        cid = r.get("canonical_id")
        if wid and cid:
            m[wid] = cid
    # ensure all work ids have a mapping (identity)
    for w in (all_works or []):
        wid = w.get("id")
        if wid:
            m.setdefault(wid, wid)
    # compress
    for wid in list(m.keys()):
        m[wid] = _root(m, wid)
    return m


def _save_map(m):
    rows = [{"work_id": wid, "canonical_id": cid} for wid, cid in sorted(m.items())]
    _write_json(MAP_FILE, rows)


def _root(m, wid):
    seen = set()
    cur = wid
    while True:
        nxt = m.get(cur, cur)
        if nxt == cur or nxt in seen:
            break
        seen.add(cur);
        cur = nxt
    for s in seen:
        m[s] = cur
    return cur


def _repoint_all_to(m, old_ids, new_id):
    old = set(old_ids)
    for wid, cid in list(m.items()):
        if cid in old:
            m[wid] = new_id
    for wid in list(m.keys()):
        m[wid] = _root(m, wid)


@app.get("/")
def index():
    return send_from_directory(app.static_folder, "index.html")


@app.get("/static/<path:p>")
def static_files(p):
    return send_from_directory(app.static_folder, p)


@app.get("/api/authors")
def authors():
    _reload()
    theos = CACHE["theologians"]
    out = [{"id": t.get("id"),
            "full_name": t.get("full_name") or t.get("name"),
            "dates": t.get("dates"),
            "key_work_ids": t.get("key_work_ids") or []}
           for t in theos]
    out.sort(key=lambda x: (x["full_name"] or ""))
    return jsonify(out)


@app.get("/api/works")
def works_by_author():
    _reload()
    author_id = request.args.get("author_id")
    if not author_id:
        return jsonify({"error": "author_id required"}), 400
    t = next((x for x in CACHE["theologians"] if x.get("id") == author_id), None)
    if not t:
        return jsonify([])

    want = set((t.get("key_work_ids") or []))
    out = []
    for w in CACHE["works"]:
        wid = w.get("id")
        if wid in want:
            out.append({"id": wid, "title": w.get("title")})
    out.sort(key=lambda x: (x.get("title") or "", x.get("id") or ""))
    return jsonify(out)


@app.get("/api/map")
def api_get_map():
    _reload()
    rows = [{"work_id": wid, "canonical_id": cid} for wid, cid in sorted(CACHE["canon_map"].items())]
    return jsonify(rows)


@app.post("/api/map/merge")
def api_merge():
    _reload()
    data = request.get_json(force=True, silent=True) or {}
    canonical_id = data.get("canonical_id")
    merge_ids = [x for x in (data.get("merge_ids") or []) if x and x != canonical_id]
    if not canonical_id or not merge_ids:
        return jsonify({"error": "canonical_id and merge_ids required"}), 400

    m = dict(CACHE["canon_map"])
    for wid in set([canonical_id] + merge_ids):
        m.setdefault(wid, wid)
    for mid in merge_ids:
        m[mid] = canonical_id
    _repoint_all_to(m, merge_ids, canonical_id)
    for wid in list(m.keys()):
        m[wid] = _root(m, wid)
    _save_map(m)
    CACHE["canon_map"] = m
    return jsonify({"ok": True, "canonical_id": canonical_id, "merged": merge_ids})

# %%
theologians = CACHE["theologians"] = _load_json(THEO_FILE, []) or []
works = CACHE["works"] = _load_json(WORKS_FILE, []) or []

# %%
len(theologians)
# Out:
# 539

# %%
theo_names = [theo["name"] for theo in theologians]
unique_theo_names = set(theo_names)

# %%
theologians
# Out:
# [{'id': 'theo_b9515ffe8f41',
#   'slug': 'anselm-of-canterbury',
#   'full_name': 'Anselm of Canterbury',
#   'name': 'Anselm of Canterbury',
#   'dates': '1033–1109',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_d4aee8289faa',
#   'slug': 'peter-abelard',
#   'full_name': 'Peter Abelard',
#   'name': 'Peter Abelard',
#   'dates': '1079–1142',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_f0740853d304',
#   'slug': 'thomas-aquinas',
#   'full_name': 'Thomas Aquinas',
#   'name': 'Thomas Aquinas',
#   'dates': '1225–1274',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_4957eb6ae45c',
#   'slug': 'martin-luther',
#   'full_name': 'Martin Luther',
#   'name': 'Martin Luther',
#   'dates': '1483–1546',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_4f9899419004',
#   'slug': 'huldrych-zwingli',
#   'full_name': 'Huldrych Zwingli',
#   'name': 'Huldrych Zwingli',
#   'dates': '1484–1531',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_981ba1a87816',
#   'slug': 'martin-bucer',
#   'full_name': 'Martin Bucer',
#   'name': 'Martin Bucer',
#   'dates': '1491–1551',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_1a0567e316f5',
#   'slug': 'peter-martyr-vermigli',
#   'full_name': 'Peter Martyr Vermigli',
#   'name': 'Peter Martyr Vermigli',
#   'dates': '1499–1562',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_c008d896dad3',
#   'slug': 'heinrich-bullinger',
#   'full_name': 'Heinrich Bullinger',
#   'name': 'Heinrich Bullinger',
#   'dates': '1504–1575',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_a1d8cf894ef6',
#   'slug': 'john-calvin',
#   'full_name': 'John Calvin',
#   'name': 'John Calvin',
#   'dates': '1509–1564',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_a35f13aff193',
#   'slug': 'jerome-zanchi',
#   'full_name': 'Jerome Zanchi',
#   'name': 'Jerome Zanchi',
#   'dates': '1516–1590',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_b458d70aea1b',
#   'slug': 'theodore-beza',
#   'full_name': 'Theodore Beza',
#   'name': 'Theodore Beza',
#   'dates': '1519–1605',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_3ef527d8435d',
#   'slug': 'martin-chemnitz',
#   'full_name': 'Martin Chemnitz',
#   'name': 'Martin Chemnitz',
#   'dates': '1522–1586',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_6972ef3bdeb3',
#   'slug': 'zacharias-ursinus',
#   'full_name': 'Zacharias Ursinus',
#   'name': 'Zacharias Ursinus',
#   'dates': '1534–1583',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_7eb7c44e03df',
#   'slug': 'luis-de-molina',
#   'full_name': 'Luis de Molina',
#   'name': 'Luis de Molina',
#   'dates': '1535–1600',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_4d5360a0b60c',
#   'slug': 'thomas-cartwright',
#   'full_name': 'Thomas Cartwright',
#   'name': 'Thomas Cartwright',
#   'dates': '1535–1603',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_12c54f5dccd0',
#   'slug': 'caspar-olevianus',
#   'full_name': 'Caspar Olevianus',
#   'name': 'Caspar Olevianus',
#   'dates': '1536–1587',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_bdebefdda6e2',
#   'slug': 'robert-bellarmine',
#   'full_name': 'Robert Bellarmine',
#   'name': 'Robert Bellarmine',
#   'dates': '1542–1621',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_eed6743a8a26',
#   'slug': 'william-whitaker',
#   'full_name': 'William Whitaker',
#   'name': 'William Whitaker',
#   'dates': '1548–1595',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_9d1c9e716e52',
#   'slug': 'william-perkins',
#   'full_name': 'William Perkins',
#   'name': 'William Perkins',
#   'dates': '1558–1602',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_751289717f03',
#   'slug': 'jacobus-arminius',
#   'full_name': 'Jacobus Arminius',
#   'name': 'Jacobus Arminius',
#   'dates': '1560–1609',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_2498929fd72b',
#   'slug': 'hugo-grotius',
#   'full_name': 'Hugo Grotius',
#   'name': 'Hugo Grotius',
#   'dates': '1583–1645',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_135b43c4081d',
#   'slug': 'john-ball',
#   'full_name': 'John Ball',
#   'name': 'John Ball',
#   'dates': '1585–1640',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_de14dfbee36e',
#   'slug': 'samuel-rutherford',
#   'full_name': 'Samuel Rutherford',
#   'name': 'Samuel Rutherford',
#   'dates': '1600–1661',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_76676de8df3a',
#   'slug': 'johannes-cocceius',
#   'full_name': 'Johannes Cocceius',
#   'name': 'Johannes Cocceius',
#   'dates': '1603–1669',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_06305c7dfd89',
#   'slug': 'thomas-brooks',
#   'full_name': 'Thomas Brooks',
#   'name': 'Thomas Brooks',
#   'dates': '1608–1680',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_be26c8815459',
#   'slug': 'richard-baxter',
#   'full_name': 'Richard Baxter',
#   'name': 'Richard Baxter',
#   'dates': '1615–1691',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_01884231e7c8',
#   'slug': 'john-owen',
#   'full_name': 'John Owen',
#   'name': 'John Owen',
#   'dates': '1616–1683',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_615bf9a64d03',
#   'slug': 'patrick-gillespie',
#   'full_name': 'Patrick Gillespie',
#   'name': 'Patrick Gillespie',
#   'dates': '1617–1675',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_4adfd8bebd91',
#   'slug': 'francis-turretin',
#   'full_name': 'Francis Turretin',
#   'name': 'Francis Turretin',
#   'dates': '1623–1687',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_3ec37db888cb',
#   'slug': 'stephen-charnock',
#   'full_name': 'Stephen Charnock',
#   'name': 'Stephen Charnock',
#   'dates': '1628–1680',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_4ed71d2f14b4',
#   'slug': 'petrus-van-mastricht',
#   'full_name': 'Petrus van Mastricht',
#   'name': 'Petrus van Mastricht',
#   'dates': '1630–1706',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_5fc1ca9b6f7c',
#   'slug': 'herman-witsius',
#   'full_name': 'Herman Witsius',
#   'name': 'Herman Witsius',
#   'dates': '1636–1708',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_e482a45012cc',
#   'slug': 'westminster-standards',
#   'full_name': 'Westminster Standards',
#   'name': 'Westminster Standards',
#   'dates': '1646–1647',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_e9d0ddafe642',
#   'slug': 'gottfried-wilhelm-leibniz',
#   'full_name': 'Gottfried Wilhelm Leibniz',
#   'name': 'Gottfried Wilhelm Leibniz',
#   'dates': '1646–1716',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_2a4f308c7e0f',
#   'slug': 'three-forms-of-unity',
#   'full_name': 'Three Forms of Unity',
#   'name': 'Three Forms of Unity',
#   'dates': '16th–17th c.',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_52c85aceaf14',
#   'slug': 'jonathan-edwards',
#   'full_name': 'Jonathan Edwards',
#   'name': 'Jonathan Edwards',
#   'dates': '1703–1758',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_8a3c071853cc'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_8b3fc578947f',
#   'slug': 'andrew-fuller',
#   'full_name': 'Andrew Fuller',
#   'name': 'Andrew Fuller',
#   'dates': '1754–1815',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_592b834e385e',
#   'slug': 'friedrich-schleiermacher',
#   'full_name': 'Friedrich Schleiermacher',
#   'name': 'Friedrich Schleiermacher',
#   'dates': '1768–1834',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_991f5a107a5c',
#   'slug': 'charles-hodge',
#   'full_name': 'Charles Hodge',
#   'name': 'Charles Hodge',
#   'dates': '1797–1878',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_7db70259efee',
#    'work_0fcf04d6f344',
#    'work_6c740aa6d58d',
#    'work_792e97ac034b',
#    'work_87f6fe39d6ed',
#    'work_9ed150331cd1',
#    'work_6e09b6d6074d',
#    'work_0483c6201cdb',
#    'work_c4909d4ecb8d',
#    'work_e4b135d1f721',
#    'work_0660a13c428b',
#    'work_c8bfdebbb234',
#    'work_3a8a91717f81',
#    'work_70e28aeb8b8a',
#    'work_ff00388ff0c1',
#    'work_d3593d216050',
#    'work_e39886286879',
#    'work_eb67b8fef7be',
#    'work_4d5332295fbe',
#    'work_8c49ddb99bf1',
#    'work_5aa6ab6bf643',
#    'work_5f9be24ab193',
#    'work_9a094643924c',
#    'work_6837d0ed6c1d'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_42f5f72cb724',
#   'slug': 'john-nelson-darby',
#   'full_name': 'John Nelson Darby',
#   'name': 'John Nelson Darby',
#   'dates': '1800–1882',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_8f38ba1661f8',
#   'slug': 'john-williamson-nevin',
#   'full_name': 'John Williamson Nevin',
#   'name': 'John Williamson Nevin',
#   'dates': '1803–1886',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_3a9d2c132afb',
#   'slug': 'patrick-fairbairn',
#   'full_name': 'Patrick Fairbairn',
#   'name': 'Patrick Fairbairn',
#   'dates': '1805–1874',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_082b15f5fc01',
#   'slug': 'james-bannerman',
#   'full_name': 'James Bannerman',
#   'name': 'James Bannerman',
#   'dates': '1807–1868',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_6f22574f46ca', 'work_f4a8407ecc3a'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_deba605e3a95',
#   'slug': 'andrew-a.-bonar',
#   'full_name': 'Andrew A. Bonar',
#   'name': 'Andrew A. Bonar',
#   'dates': '1810–1892',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_e47d914e0621',
#   'slug': 'philip-schaff',
#   'full_name': 'Philip Schaff',
#   'name': 'Philip Schaff',
#   'dates': '1819–1893',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_c4bd273d811a',
#   'slug': 'robert-l.-dabney',
#   'full_name': 'Robert L. Dabney',
#   'name': 'Robert L. Dabney',
#   'dates': '1820–1898',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_5d58d49d85c1',
#   'slug': 'hugh-martin',
#   'full_name': 'Hugh Martin',
#   'name': 'Hugh Martin',
#   'dates': '1822–1885',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_fd6d1af54939',
#   'slug': 'albrecht-ritschl',
#   'full_name': 'Albrecht Ritschl',
#   'name': 'Albrecht Ritschl',
#   'dates': '1822–1889',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_e85d71513e95',
#   'slug': 'a.a.-hodge',
#   'full_name': 'A.A. Hodge',
#   'name': 'A.A. Hodge',
#   'dates': '1823–1886',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_a1dc6864e0b1'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_f18f96e39d2b',
#   'slug': 'andrew-murray',
#   'full_name': 'Andrew Murray',
#   'name': 'Andrew Murray',
#   'dates': '1828–1917',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_bbaf9204ff14',
#   'slug': 'abraham-kuyper',
#   'full_name': 'Abraham Kuyper',
#   'name': 'Abraham Kuyper',
#   'dates': '1837–1920',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_a179e488f8ad'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_693470de5594',
#   'slug': 'c.i.-scofield',
#   'full_name': 'C.I. Scofield',
#   'name': 'C.I. Scofield',
#   'dates': '1843–1921',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_88b1662fb76c',
#   'slug': 'p.t.-forsyth',
#   'full_name': 'P.T. Forsyth',
#   'name': 'P.T. Forsyth',
#   'dates': '1848–1921',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_0fb2dd147a7b',
#   'slug': 'benjamin-b.-warfield',
#   'full_name': 'B.B. Warfield',
#   'name': 'B.B. Warfield',
#   'dates': '1851–1921',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_663e8e5cf3e2',
#    'work_55bb9a43fa48',
#    'work_d279b88ba88f',
#    'work_db54d02c3bbe',
#    'work_b75b04b61ee3',
#    'work_0344af5c5679',
#    'work_6f805ced1670',
#    'work_4dbae5e8080f',
#    'work_8ed8eecea547',
#    'work_d0b75ffea339',
#    'work_bfc968a6db4c',
#    'work_d0cf4ee56f9a',
#    'work_fb77a060d596',
#    'work_a7b81d7920e4',
#    'work_5e64b6fafebe',
#    'work_ea2befff6838',
#    'work_9dff1e065f4a',
#    'work_3050602e5b24',
#    'work_3eb424ddb6e6',
#    'work_8e5e904fd9ab',
#    'work_60df5e01e1a4',
#    'work_08b2de69f837',
#    'work_7e1da77dd255',
#    'work_08ff27696886',
#    'work_d327a623c9fa',
#    'work_b071fc4a6029',
#    'work_634909e68eab',
#    'work_2ee6da8bea75',
#    'work_13cca635cddd',
#    'work_a613f75fdd62',
#    'work_a225ecb403cd',
#    'work_1fa1b45c418d',
#    'work_bafef35e59ca',
#    'work_f6c23d324196',
#    'work_8e685d58cc09'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_536313221b01',
#   'slug': 'charles-gore',
#   'full_name': 'Charles Gore',
#   'name': 'Charles Gore',
#   'dates': '1853–1932',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_aff4ec250119',
#   'slug': 'herman-bavinck',
#   'full_name': 'Herman Bavinck',
#   'name': 'Herman Bavinck',
#   'dates': '1854–1921',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_1c0566e3d363',
#   'slug': 'geerhardus-vos',
#   'full_name': 'Geerhardus Vos',
#   'name': 'Geerhardus Vos',
#   'dates': '1862–1949',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_4a836dd5db90',
#    'work_e76b3479e361',
#    'work_41e633c2a56d',
#    'work_9f81a095ae1e',
#    'work_b96b775a5283',
#    'work_1fff5ebc32cc',
#    'work_e3d99cfce0ad',
#    'work_8afaeebfdbe4',
#    'work_bae452e18aad',
#    'work_89f1fbae6a40',
#    'work_ffc066a002e4',
#    'work_bc6e435f5670',
#    'work_77e715fc9599',
#    'work_70de98a97a97',
#    'work_45c31c35cc25',
#    'work_dd674a00a913',
#    'work_c643356f2fe6',
#    'work_7a68411ef3a3',
#    'work_7d2c154d5d1c',
#    'work_949d43d090b1',
#    'work_06e2d42d409a',
#    'work_b41f5e67f02e',
#    'work_00689e61b046',
#    'work_dedc186541e8'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_48f5a58084c6',
#   'slug': 'h.r.-mackintosh',
#   'full_name': 'H.R. Mackintosh',
#   'name': 'H.R. Mackintosh',
#   'dates': '1870–1936',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_1252b62e6729',
#   'slug': 'lewis-sperry-chafer',
#   'full_name': 'Lewis Sperry Chafer',
#   'name': 'Lewis Sperry Chafer',
#   'dates': '1871–1952',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_05e253e24a0f',
#   'slug': 'louis-berkhof',
#   'full_name': 'Louis Berkhof',
#   'name': 'Louis Berkhof',
#   'dates': '1873–1957',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_bf6d340274b7',
#   'slug': 'j.-gresham-machen',
#   'full_name': 'J. Gresham Machen',
#   'name': 'J. Gresham Machen',
#   'dates': '1881–1937',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_6f41a2a4bf2f',
#    'work_76c201ed2863',
#    'work_4a565f98e922',
#    'work_14e574b12f75',
#    'work_17b46ec99fb7',
#    'work_0e3e122b61c6',
#    'work_f946d80a1b8b',
#    'work_091b2ba7d4cd',
#    'work_c716d185b3e1'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_c511a0393025',
#   'slug': 'c.h.-dodd',
#   'full_name': 'C.H. Dodd',
#   'name': 'C.H. Dodd',
#   'dates': '1884–1973',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_888da193d4d0',
#   'slug': 'rudolf-bultmann',
#   'full_name': 'Rudolf Bultmann',
#   'name': 'Rudolf Bultmann',
#   'dates': '1884–1976',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_124906e9ce1f',
#   'slug': 'paul-tillich',
#   'full_name': 'Paul Tillich',
#   'name': 'Paul Tillich',
#   'dates': '1886–1965',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_576aa8dc749e',
#   'slug': 'karl-barth',
#   'full_name': 'Karl Barth',
#   'name': 'Karl Barth',
#   'dates': '1886–1968',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_c0f849d47ff5',
#    'work_6db748cfb8d9',
#    'work_4826585f07a0',
#    'work_efd2e53817c1',
#    'work_a7b323669dce'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_5ce5eb6d4e76',
#   'slug': 'emil-brunner',
#   'full_name': 'Emil Brunner',
#   'name': 'Emil Brunner',
#   'dates': '1889–1966',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_5de3eab8e8ad'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_c2678a5b805f',
#   'slug': 'erich-przywara',
#   'full_name': 'Erich Przywara',
#   'name': 'Erich Przywara',
#   'dates': '1889–1972',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_ff69d567b651',
#   'slug': 'cornelius-van-til',
#   'full_name': 'Cornelius Van Til',
#   'name': 'Cornelius Van Til',
#   'dates': '1895–1987',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_ee43657ddf33',
#    'work_175908b0d5ec',
#    'work_30de79418804',
#    'work_c1b6a7a8b11f',
#    'work_fe0ffc3352ce',
#    'work_72fee4520fc3',
#    'work_d47f3eb8e12f',
#    'work_7a96595e90bf',
#    'work_1409c60695dc',
#    'work_63968be99409',
#    'work_ad4dc8b68f6a',
#    'work_65822dd31a7d'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_b4bdac2460b6',
#   'slug': 'james-s.-stewart',
#   'full_name': 'James S. Stewart',
#   'name': 'James S. Stewart',
#   'dates': '1896–1990',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_0967b706d70a',
#   'slug': 'john-murray',
#   'full_name': 'John Murray',
#   'name': 'John Murray',
#   'dates': '1898–1975',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_9325bb4f2b0f',
#    'work_5d725dd1b15c',
#    'work_68c6304e8021',
#    'work_5bd70010aa12',
#    'work_2d17b56fbce8',
#    'work_0791b8985613',
#    'work_e331e57dd9f1',
#    'work_d3acaaa04609',
#    'work_b067e3a97e45',
#    'work_d49529b4851e',
#    'work_83de20168f97',
#    'work_001e372b053f',
#    'work_ab0928eb1b08',
#    'work_ddd2c88dbd1c',
#    'work_3b4fd9208f83',
#    'work_5b049cbd9896',
#    'work_bf2e16220be9',
#    'work_d1d5d9ab9390',
#    'work_ec57d3b0f685',
#    'work_722f954c8c54',
#    'work_01a63d4fb3cc',
#    'work_1efe8e840118',
#    'work_678937bff8ba',
#    'work_b6ae5d109921',
#    'work_c46874076ce2',
#    'work_575b84a008ff',
#    'work_5b542650e248',
#    'work_281bab4362d9',
#    'work_7ab43e4c9999',
#    'work_c346d3b01cc9',
#    'work_a6dbe504d658',
#    'work_946775c6295e',
#    'work_d32627fcd5cc'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_4e646fb46d71',
#   'slug': 'martyn-lloyd-jones',
#   'full_name': 'Martyn Lloyd-Jones',
#   'name': 'Martyn Lloyd-Jones',
#   'dates': '1899–1981',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_fa865183aa95',
#   'slug': 'jeremias-joachim',
#   'full_name': 'Joachim Jeremias',
#   'name': 'Joachim Jeremias',
#   'dates': '1900–1979',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_449e30a58c98',
#   'slug': 'oscar-cullmann',
#   'full_name': 'Oscar Cullmann',
#   'name': 'Oscar Cullmann',
#   'dates': '1902–1999',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_cc8f0d6da7ba'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_3437f4446328',
#   'slug': 'vladimir-lossky',
#   'full_name': 'Vladimir Lossky',
#   'name': 'Vladimir Lossky',
#   'dates': '1903–1958',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_3c0f75d1c11a'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_3fc45f8c5a0a',
#   'slug': 'g.c.-berkouwer',
#   'full_name': 'G.C. Berkouwer',
#   'name': 'G.C. Berkouwer',
#   'dates': '1903–1996',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_e4743adb5eea', 'work_7d009b3b452c'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_58387045c6b4',
#   'slug': 'karl-rahner',
#   'full_name': 'Karl Rahner',
#   'name': 'Karl Rahner',
#   'dates': '1904–1984',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_e9a9cb2ea41a',
#   'slug': 'hans-urs-von-balthasar',
#   'full_name': 'Hans Urs von Balthasar',
#   'name': 'Hans Urs von Balthasar',
#   'dates': '1905–1988',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_4fee92d32985',
#   'slug': 'edward-j.-young',
#   'full_name': 'Edward J. Young',
#   'name': 'Edward J. Young',
#   'dates': '1907–1968',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_82ae971d185f',
#   'slug': 'lesslie-newbigin',
#   'full_name': 'Lesslie Newbigin',
#   'name': 'Lesslie Newbigin',
#   'dates': '1909–1998',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_5cf11cb076fe',
#   'slug': 'herman-ridderbos',
#   'full_name': 'Herman Ridderbos',
#   'name': 'Herman Ridderbos',
#   'dates': '1909–2007',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_8690eaaebbe4'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_f249d2ac97ac',
#   'slug': 'f.f.-bruce',
#   'full_name': 'F.F. Bruce',
#   'name': 'F.F. Bruce',
#   'dates': '1910–1990',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_602211ff3feb',
#   'slug': 'george-eldon-ladd',
#   'full_name': 'George Eldon Ladd',
#   'name': 'George Eldon Ladd',
#   'dates': '1911–1982',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_f16c96be5523'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_776c109f14d3',
#   'slug': 'anthony-a.-hoekema',
#   'full_name': 'Anthony Hoekema',
#   'name': 'Anthony Hoekema',
#   'dates': '1913–1988',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_7408a4fd2b22',
#    'work_602d985ec253',
#    'work_3abde47e6d64',
#    'work_8830c806280d',
#    'work_dfc1fdb40ade'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_bf8ba6c7a258',
#   'slug': 'harold-lindsell',
#   'full_name': 'Harold Lindsell',
#   'name': 'Harold Lindsell',
#   'dates': '1913–1998',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_eeaa72b8f356',
#   'slug': 't.f.-torrance',
#   'full_name': 'Thomas F. Torrance',
#   'name': 'Thomas F. Torrance',
#   'dates': '1913–2007',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_0d24801e6402',
#    'work_c485c583cf7b',
#    'work_49b7e746f7b0',
#    'work_03b33aef7166',
#    'work_3bec97849cb4'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_f8cdf45b0651',
#   'slug': 'john-gerstner',
#   'full_name': 'John Gerstner',
#   'name': 'John Gerstner',
#   'dates': '1914–1996',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_34a41f98aa23',
#   'slug': 'bruce-metzger',
#   'full_name': 'Bruce Metzger',
#   'name': 'Bruce Metzger',
#   'dates': '1914–2007',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_81db768c415a',
#   'slug': 'edmund-p.-clowney',
#   'full_name': 'Edmund P. Clowney',
#   'name': 'Edmund P. Clowney',
#   'dates': '1917–2005',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_250706d8adcb',
#    'work_321a600ee5e7',
#    'work_2b03af25e784'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_d30bb9cb60a4',
#   'slug': 'john-stott',
#   'full_name': 'John Stott',
#   'name': 'John Stott',
#   'dates': '1921–2011',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_2752fab85e36'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_7ab423f6dffc',
#   'slug': 'meredith-g.-kline',
#   'full_name': 'Meredith G. Kline',
#   'name': 'Meredith G. Kline',
#   'dates': '1922–2007',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_7f0f18ba1c93',
#    'work_0b5dca0d533c',
#    'work_9fc57c0c0bdf',
#    'work_17b252f5192d',
#    'work_8705ff2e1e89',
#    'work_00319377d508',
#    'work_550cd1a1596b',
#    'work_64798e251835'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_72343e4634e6',
#   'slug': 'john-hick',
#   'full_name': 'John Hick',
#   'name': 'John Hick',
#   'dates': '1922–2012',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_0fac293fe6ab',
#   'slug': 'james-b.-torrance',
#   'full_name': 'James B. Torrance',
#   'name': 'James B. Torrance',
#   'dates': '1923–2003',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_2f4c9a9e2de9',
#   'slug': 'james-barr',
#   'full_name': 'James Barr',
#   'name': 'James Barr',
#   'dates': '1924–2006',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_b83de096b3f6'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_460f372a5a47',
#   'slug': 'alec-motyer',
#   'full_name': 'Alec Motyer',
#   'name': 'Alec Motyer',
#   'dates': '1924–2016',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_d2e09146feb8',
#   'slug': 'charles-c.-ryrie',
#   'full_name': 'Charles C. Ryrie',
#   'name': 'Charles C. Ryrie',
#   'dates': '1925–2016',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_09edae13e8c2',
#   'slug': 'jrgen-moltmann',
#   'full_name': 'Jürgen Moltmann',
#   'name': 'Jürgen Moltmann',
#   'dates': '1926–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_3229cd5a4c45',
#    'work_13906d6bac94',
#    'work_8ba0d271214b',
#    'work_0642066c1c33',
#    'work_e8e0d1b376b5',
#    'work_0c83fbaa24d9',
#    'work_9b03e4a1c3b0',
#    'work_1310f4ce41ea'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_4c092cfc0ab2',
#   'slug': 'j.i.-packer',
#   'full_name': 'J.I. Packer',
#   'name': 'J.I. Packer',
#   'dates': '1926–2020',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_717508b79e66', 'work_19d6f7c14885'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_fdb0163ae082',
#   'slug': 'wolfhart-pannenberg',
#   'full_name': 'Wolfhart Pannenberg',
#   'name': 'Wolfhart Pannenberg',
#   'dates': '1928–2014',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_1c402df6703c'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_a71d06ea1b9a',
#   'slug': 'bruce-k.-waltke',
#   'full_name': 'Bruce K. Waltke',
#   'name': 'Bruce K. Waltke',
#   'dates': '1930–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_97af3838b55c',
#   'slug': 'robert-jenson',
#   'full_name': 'Robert Jenson',
#   'name': 'Robert Jenson',
#   'dates': '1930–2017',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_0e1613ce8227',
#    'work_768989aa4b1a',
#    'work_fb67824231a6'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_978af2b7052c',
#   'slug': 'john-zizioulas',
#   'full_name': 'John Zizioulas',
#   'name': 'John Zizioulas',
#   'dates': '1931–2023',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_53cc9f912144',
#   'slug': 'alvin-plantinga',
#   'full_name': 'Alvin Plantinga',
#   'name': 'Alvin Plantinga',
#   'dates': '1932–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_5fe9b994d35a',
#    'work_35e3b9e28870',
#    'work_4bd6d1f421e1'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_54ea2b02ca75',
#   'slug': 'millard-j.-erickson',
#   'full_name': 'Millard J. Erickson',
#   'name': 'Millard J. Erickson',
#   'dates': '1932–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_0a434df2723d',
#   'slug': 'nicholas-wolterstorff',
#   'full_name': 'Nicholas Wolterstorff',
#   'name': 'Nicholas Wolterstorff',
#   'dates': '1932–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_c72643517ce2', 'work_7caf6308f4f4'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_dec387d5182b',
#   'slug': 'philip-hefner',
#   'full_name': 'Philip Hefner',
#   'name': 'Philip Hefner',
#   'dates': '1932–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_f466650f9791'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_79a75722c278',
#   'slug': 'robert-b.-strimple',
#   'full_name': 'Robert B. Strimple',
#   'name': 'Robert B. Strimple',
#   'dates': '1932–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_1e3f008aa06e'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_f36e6cafc661',
#   'slug': 'robert-gundry',
#   'full_name': 'Robert Gundry',
#   'name': 'Robert Gundry',
#   'dates': '1932–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_1399c233d6b2', 'work_e535d707a312'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_334cf2b7246e',
#   'slug': 'robert-l.-reymond',
#   'full_name': 'Robert L. Reymond',
#   'name': 'Robert L. Reymond',
#   'dates': '1932–2013',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_3dd98bc60edf'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_3940e777a6d5',
#   'slug': 'hughes-oliphant-old',
#   'full_name': 'Hughes Oliphant Old',
#   'name': 'Hughes Oliphant Old',
#   'dates': '1933–2016',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_c8e258c8a5b2'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_528d1919f651',
#   'slug': 'norman-shepherd',
#   'full_name': 'Norman Shepherd',
#   'name': 'Norman Shepherd',
#   'dates': '1933–2020',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_e378f2f89e1b', 'work_c04fde703a61'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_3de7f5e8105a',
#   'slug': 'richard-swinburne',
#   'full_name': 'Richard Swinburne',
#   'name': 'Richard Swinburne',
#   'dates': '1934–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_4517364946b5'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_a71d3f984e96',
#   'slug': 'robert-sokolowski',
#   'full_name': 'Robert Sokolowski',
#   'name': 'Robert Sokolowski',
#   'dates': '1934–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_2b6e25aeb441',
#   'slug': 'i.-howard-marshall',
#   'full_name': 'I. Howard Marshall',
#   'name': 'I. Howard Marshall',
#   'dates': '1934–2015',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_593ce2666851',
#   'slug': 'eberhard-jngel',
#   'full_name': 'Eberhard Jüngel',
#   'name': 'Eberhard Jüngel',
#   'dates': '1934–2021',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_97952d3f743d',
#   'slug': 'gordon-d.-fee',
#   'full_name': 'Gordon Fee',
#   'name': 'Gordon Fee',
#   'dates': '1934–2022',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_3256020d5aef', 'work_7ecda1b3c00a'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_e6814c63374f',
#   'slug': 'graeme-goldsworthy',
#   'full_name': 'Graeme Goldsworthy',
#   'name': 'Graeme Goldsworthy',
#   'dates': '1934–2023',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_239bae3ce5fe'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_ba1286686f3e',
#   'slug': 'sidney-greidanus',
#   'full_name': 'Sidney Greidanus',
#   'name': 'Sidney Greidanus',
#   'dates': '1935–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_4aadc4fcb550'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_01d6e8e3cff7',
#   'slug': 'richard-b.-gaffin-jr.',
#   'full_name': 'Richard B. Gaffin Jr.',
#   'name': 'Richard B. Gaffin Jr.',
#   'dates': '1936–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_120049788b35',
#    'work_c8a9ddae7dab',
#    'work_ef7ee16d5ccf',
#    'work_8380a2b1c197',
#    'work_53f5e52e47ef',
#    'work_91186fc80a9b',
#    'work_d9cd873f21f0',
#    'work_77307979380d',
#    'work_31f26f082956',
#    'work_811428f75178',
#    'work_1a1becb74547',
#    'work_8b7a341f1bba',
#    'work_e9be7e2b2570',
#    'work_e61d83e59d84',
#    'work_84a94616b884',
#    'work_96c5e40161e6',
#    'work_249b7d40e35f',
#    'work_9239db0ee95f',
#    'work_9cb903ec150d',
#    'work_579f9bbaafd2',
#    'work_f68c5ab25196',
#    'work_bdd85ad52147',
#    'work_82f6bed846d3',
#    'work_8594cb05c4b1',
#    'work_484b3a621281',
#    'work_2277bc20f8eb',
#    'work_4251ff44ffe8',
#    'work_c090b8357a64'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_452e8ff3c243',
#   'slug': 'richard-gaffin',
#   'full_name': 'Richard Gaffin',
#   'name': 'Richard Gaffin',
#   'dates': '1936–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_6d700232d023',
#   'slug': 'richard-john-neuhaus',
#   'full_name': 'Richard John Neuhaus',
#   'name': 'Richard John Neuhaus',
#   'dates': '1936–2009',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': [],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_14fdb72b1032',
#   'slug': 'henri-blocher',
#   'full_name': 'Henri Blocher',
#   'name': 'Henri Blocher',
#   'dates': '1937–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_699e094102d3',
#    'work_7c836ea0bf55',
#    'work_ccf76bcfc121',
#    'work_40b323c333c6'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_7b3bc848e42f',
#   'slug': 'o.-palmer-robertson',
#   'full_name': 'O. Palmer Robertson',
#   'name': 'O. Palmer Robertson',
#   'dates': '1937–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_98d326b55abd',
#    'work_7e5adcafdaa9',
#    'work_9ba9ce7a1873'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_861395e24a6a',
#   'slug': 'clark-pinnock',
#   'full_name': 'Clark Pinnock',
#   'name': 'Clark Pinnock',
#   'dates': '1937–2010',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_885b0df1541e', 'work_1ab846810c46'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_4e0b5bf3b5ab',
#   'slug': 'anthony-c.-thiselton',
#   'full_name': 'Anthony C. Thiselton',
#   'name': 'Anthony C. Thiselton',
#   'dates': '1937–2023',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_302982b8d8be'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_5294100373f4',
#   'slug': 'david-f.-wells',
#   'full_name': 'David F. Wells',
#   'name': 'David F. Wells',
#   'dates': '1939–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_c0742126db26', 'work_2ed775b10e53'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_95d2d502c3ed',
#   'slug': 'john-f.-macarthur',
#   'full_name': 'John F. MacArthur',
#   'name': 'John F. MacArthur',
#   'dates': '1939–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_0c8704070420'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_a9d7b0a5f494',
#   'slug': 'john-frame',
#   'full_name': 'John Frame',
#   'name': 'John Frame',
#   'dates': '1939–',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_6ed0c173d0ba',
#    'work_48ee329884d0',
#    'work_210011145998',
#    'work_d6dc9eb48233',
#    'work_2ae3bc5e5d02',
#    'work_6d4da1a7adce',
#    'work_6d5fe6b94485',
#    'work_2dcdecdae89c',
#    'work_cd39b9864c29',
#    'work_f9bb18cf5178',
#    'work_9c1ee1f38eb0',
#    'work_9df50aa531b7'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_5a692375b834',
#   'slug': 'r.c.-sproul',
#   'full_name': 'R.C. Sproul',
#   'name': 'R.C. Sproul',
#   'dates': '1939–2017',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_384714587efa'],
#   'wts_relevance': True,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_aebad71d8bd5',
#   'slug': 'james-d.g.-dunn',
#   'full_name': 'James D.G. Dunn',
#   'name': 'James D.G. Dunn',
#   'dates': '1939–2020',
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
# ...
#  {'id': 'theo_095e36083b58',
#   'slug': 'paul-avis',
#   'full_name': 'Paul Avis',
#   'name': 'Paul Avis',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_8e463a6637a1',
#    'work_675b46064e81',
#    'work_2ac8f1228bf6'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_08fd87050fe4',
#   'slug': 'bryan-litfin',
#   'full_name': 'Bryan Litfin',
#   'name': 'Bryan Litfin',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_b07d6beb5dd1'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_ba1e09f5b1a6',
#   'slug': 'd-g-hart',
#   'full_name': 'D.G. Hart',
#   'name': 'D.G. Hart',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_1279095d360a'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_ace23064dcf0',
#   'slug': 'l-roy-taylor',
#   'full_name': 'L. Roy Taylor',
#   'name': 'L. Roy Taylor',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_ce9d0b5b0ee1'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_0d3483216235',
#   'slug': 'john-s-hammett',
#   'full_name': 'John S. Hammett',
#   'name': 'John S. Hammett',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_fd296afda209'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_1ce9325c9e01',
#   'slug': 'steven-r-harmon',
#   'full_name': 'Steven R. Harmon',
#   'name': 'Steven R. Harmon',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_680db9c8fa74'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_d63091f14c40',
#   'slug': 'bryan-chapell',
#   'full_name': 'Bryan Chapell',
#   'name': 'Bryan Chapell',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_6da63c2ec9f5'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_4b2fcb802f99',
#   'slug': 'jonathan-a-linebaugh',
#   'full_name': 'Jonathan A. Linebaugh',
#   'name': 'Jonathan A. Linebaugh',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_5c1d3317e733'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_3da1fbc63af1',
#   'slug': 'tim-chester',
#   'full_name': 'Tim Chester',
#   'name': 'Tim Chester',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_81cba275b8e8'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_acc5ff6d02ac',
#   'slug': 'william-willimon',
#   'full_name': 'William Willimon',
#   'name': 'William Willimon',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_1827b6168304'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_d72701d54475',
#   'slug': 'paul-k-jewett',
#   'full_name': 'Paul K. Jewett',
#   'name': 'Paul K. Jewett',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_f8cf710c60a6'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_81a68570b09d',
#   'slug': 'bryan-holstrom',
#   'full_name': 'Bryan Holstrom',
#   'name': 'Bryan Holstrom',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_68d9a550ff41'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_0d51b884efe0',
#   'slug': 'jonathan-d-trigg',
#   'full_name': 'Jonathan D. Trigg',
#   'name': 'Jonathan D. Trigg',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_63c8ce58e6d0'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_57c2fd31a833',
#   'slug': 'stanley-j-grenz',
#   'full_name': 'Stanley J. Grenz',
#   'name': 'Stanley J. Grenz',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_00a87275c776'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_573911a8232d',
#   'slug': 'glen-clary',
#   'full_name': 'Glen Clary',
#   'name': 'Glen Clary',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_9f3f1189d93a'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_3670b67927c4',
#   'slug': 'paul-t-nimmo',
#   'full_name': 'Paul T. Nimmo',
#   'name': 'Paul T. Nimmo',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_001f74de0ab3'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_bc94b1a8f312',
#   'slug': 'bryan-d-spinks',
#   'full_name': 'Bryan D. Spinks',
#   'name': 'Bryan D. Spinks',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_6e4e20dc98bb', 'work_48d5438c0d05'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_fb9d41fdcf47',
#   'slug': 'james-j-cassidy',
#   'full_name': 'James J. Cassidy',
#   'name': 'James J. Cassidy',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_b959b5d1000a'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_70c4c0024cf3',
#   'slug': 'chad-van-dixhoorn',
#   'full_name': 'Chad Van Dixhoorn',
#   'name': 'Chad Van Dixhoorn',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_f08fc3e00ab9'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_04d46e79f436',
#   'slug': 'timothy-george',
#   'full_name': 'Timothy George',
#   'name': 'Timothy George',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_a64338b02e88'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_b26bc75103df',
#   'slug': 'jonathan-leeman',
#   'full_name': 'Jonathan Leeman',
#   'name': 'Jonathan Leeman',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_969c3358a69e', 'work_695739755163'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_9e493eaa7f21',
#   'slug': 'tom-greggs',
#   'full_name': 'Tom Greggs',
#   'name': 'Tom Greggs',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_fd84fdf3e6b3'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_956b6d258781',
#   'slug': 'matthew-j-tuininga',
#   'full_name': 'Matthew J. Tuininga',
#   'name': 'Matthew J. Tuininga',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_72a8d84f4dfa'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_87260f760d3b',
#   'slug': 'hunter-baker',
#   'full_name': 'Hunter Baker',
#   'name': 'Hunter Baker',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_9c83a4ae4033'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_6fc814944811',
#   'slug': 'robert-benne',
#   'full_name': 'Robert Benne',
#   'name': 'Robert Benne',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_669ef089cedd'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_73fcd48eb151',
#   'slug': 'jonathan-chaplin',
#   'full_name': 'Jonathan Chaplin',
#   'name': 'Jonathan Chaplin',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_ad0da7171c12'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_dd4e8ff43aa7',
#   'slug': 'william-cavanaugh',
#   'full_name': 'William Cavanaugh',
#   'name': 'William Cavanaugh',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_2fe8661ad51c'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_1576e6b42459',
#   'slug': 'stanley-hauerwas',
#   'full_name': 'Stanley Hauerwas',
#   'name': 'Stanley Hauerwas',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_5b5140fa4266'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_c30de6e1e9d5',
#   'slug': 'greg-k-beale',
#   'full_name': 'Greg K. Beale',
#   'name': 'Greg K. Beale',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_bcefacb5aa84',
#    'work_81541116dcf0',
#    'work_ca9641222d99'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_26b91742e60e',
#   'slug': 'christopher-w-morgan',
#   'full_name': 'Christopher W. Morgan',
#   'name': 'Christopher W. Morgan',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_d1f77e0f60a2', 'work_500b374802e1'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_c07a2449d8c9',
#   'slug': 'grant-r-osborne',
#   'full_name': 'Grant R. Osborne',
#   'name': 'Grant R. Osborne',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_f3853fad7abb', 'work_67cbba483407'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_cfbca7daed15',
#   'slug': 'ian-paul',
#   'full_name': 'Ian Paul',
#   'name': 'Ian Paul',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_9278c86fb7b1'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_6423083cc7b1',
#   'slug': 'mark-s-kinzer',
#   'full_name': 'Mark S. Kinzer',
#   'name': 'Mark S. Kinzer',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_6a6ab5d88d6c'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_0d0f9414309b',
#   'slug': 'michael-barram',
#   'full_name': 'Michael Barram',
#   'name': 'Michael Barram',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_68510df66cc6'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_76e951abcdd2',
#   'slug': 'christopher-zoccali',
#   'full_name': 'Christopher Zoccali',
#   'name': 'Christopher Zoccali',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_21bc55c8aa5a'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_3733edc32d1d',
#   'slug': 'david-l-turner',
#   'full_name': 'David L. Turner',
#   'name': 'David L. Turner',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_f48a47ad158d'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_179780654878',
#   'slug': 'david-rudolph',
#   'full_name': 'David Rudolph',
#   'name': 'David Rudolph',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_790c1a9a59b9'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_4a90c1438322',
#   'slug': 'brant-pitre',
#   'full_name': 'Brant Pitre',
#   'name': 'Brant Pitre',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_3bbfd5f66cb4'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_187a96bb3fca',
#   'slug': 'richard-b-hays',
#   'full_name': 'Richard B. Hays',
#   'name': 'Richard B. Hays',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_493c2bcf092d'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_80f4dd48987a',
#   'slug': 'steve-gregg',
#   'full_name': 'Steve Gregg',
#   'name': 'Steve Gregg',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_e1a776b4f534'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_88121651ccae',
#   'slug': 'ian-boxall',
#   'full_name': 'Ian Boxall',
#   'name': 'Ian Boxall',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_7ff1f4da5e0d'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_0dd07dbef6a5',
#   'slug': 'j-webb-mealy',
#   'full_name': 'J. Webb Mealy',
#   'name': 'J. Webb Mealy',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_cb0c410d12a6'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_bd8b00bdfaaf',
#   'slug': 'alan-s-bandy',
#   'full_name': 'Alan S. Bandy',
#   'name': 'Alan S. Bandy',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_c9284bfe9f72'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_6bb612e00c70',
#   'slug': 'kenneth-l-gentry-jr',
#   'full_name': 'Kenneth L. Gentry Jr.',
#   'name': 'Kenneth L. Gentry Jr.',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_f577b8d4def6'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_855fadb0f054',
#   'slug': 'matthew-waymeyer',
#   'full_name': 'Matthew Waymeyer',
#   'name': 'Matthew Waymeyer',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_be511ac7d825'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_06975300b24a',
#   'slug': 'jerry-l-walls',
#   'full_name': 'Jerry L. Walls',
#   'name': 'Jerry L. Walls',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_61ad0c29fe74'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'},
#  {'id': 'theo_c8062bc70187',
#   'slug': 'matthew-kaemingk',
#   'full_name': 'Matthew Kaemingk',
#   'name': 'Matthew Kaemingk',
#   'dates': None,
#   'era_category': [],
#   'traditions': [],
#   'bio': '',
#   'timeline': [],
#   'key_work_ids': ['work_5949bf49e489'],
#   'wts_relevance': False,
#   'created_at': '2025-08-16',
#   'updated_at': '2025-08-16'}]

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Build an index of work -> theologians (authors) from your datasets.

Inputs (from DATA_DIR or ../theo-site/data by default):
  - theologians.json
  - works.json
  - outlines.jsonl (optional; improves inference)

Output:
  - data/work_authors_index.json  (list of rows)
"""

import os, json, pathlib, collections

ROOT = pathlib.Path(".").parent.resolve()
DATA_DIR = pathlib.Path(os.getenv("DATA_DIR", ROOT / "../data")).resolve()

THEO_FILE = DATA_DIR / "theologians.json"
WORKS_FILE = DATA_DIR / "works.json"
OUTLINES_L = DATA_DIR / "outlines.jsonl"
OUT_FILE = DATA_DIR / "work_authors_index.json"
canonical_map_file = DATA_DIR / "work_canon_map.json"
BY_WORK_FILE = DATA_DIR / "indices/by_work.json"
BY_THEOLOGIAN_FILE = DATA_DIR / "indices/by_theologian.json"


def read_json(p, default=None):
    try:
        return json.loads(p.read_text(encoding="utf-8"))
    except FileNotFoundError:
        return default


def read_jsonl(p):
    try:
        lines = p.read_text(encoding="utf-8").splitlines()
    except FileNotFoundError:
        return []
    out = []
    for line in lines:
        line = line.strip()
        if not line:
            continue
        try:
            out.append(json.loads(line))
        except Exception:
            pass
    return out


def to_id_list(authors):
    """Normalize a 'authors' field (list of ids or objects) -> list of ids"""
    out = []
    for a in authors or []:
        if isinstance(a, str):
            out.append(a)
        elif isinstance(a, dict):
            # prefer an explicit id if present
            if a.get("id"):
                out.append(a["id"])
            # sometimes only slug/full_name present; skip here (resolved later by name match)
    return [x for x in out if x]


def build_theo_name_maps(theologians):
    by_id = {t.get("id"): t for t in theologians if t.get("id")}
    # name/slug -> id for fallback matching if needed
    name_to_id = {}
    for t in theologians:
        tid = t.get("id")
        if not tid: continue
        for k in ("full_name", "name", "slug"):
            v = (t.get(k) or "").strip()
            if v:
                name_to_id.setdefault(v, tid)
    return by_id, name_to_id


def resolve_from_outlines(outlines):
    """Return: dict[work_id] -> Counter(theologian_id) from outline citations."""
    ctr = collections.defaultdict(collections.Counter)
    for o in outlines or []:
        tid = o.get("theologian_id")
        if not tid: continue
        for wid in (o.get("key_work_ids") or []):
            if wid:
                ctr[wid][tid] += 1
    return ctr


def main():
    theologians = read_json(THEO_FILE, []) or []
    works = read_json(WORKS_FILE, []) or []
    outlines = read_jsonl(OUTLINES_L) or []

    theo_by_id, name_to_id = build_theo_name_maps(theologians)
    outline_counts = resolve_from_outlines(outlines)  # work_id -> Counter(tid)

    rows = []
    for w in works:
        wid = w.get("id")
        title = w.get("title")
        if not wid:
            continue

        # 1) primary id
        primary_id = w.get("primary_author_theologian_id")

        # 2) authors[] → ids
        explicit_ids = to_id_list(w.get("authors"))

        # If authors[] contains only inline objects with names, try to map by name
        if not explicit_ids:
            inline_objs = [a for a in (w.get("authors") or []) if isinstance(a, dict)]
            for a in inline_objs:
                name = (a.get("full_name") or a.get("name") or "").strip()
                slug = (a.get("slug") or "").strip()
                guess = name_to_id.get(name) or name_to_id.get(slug)
                if guess:
                    explicit_ids.append(guess)

        # 3) inference from outlines (only if nothing above)
        inferred = False
        inferred_ids = []
        if not primary_id and not explicit_ids:
            counts = outline_counts.get(wid, collections.Counter())
            if counts:
                # choose the most frequent theologian; require >1 citation to reduce noise
                tid, n = counts.most_common(1)[0]
                if n >= 2:
                    primary_id = tid
                    inferred = True
                else:
                    # still keep all seen ids as secondary authors (weak signal)
                    inferred_ids = [t for t, _ in counts.most_common()]

        # Build final id list
        author_ids = []
        if primary_id: author_ids.append(primary_id)
        author_ids.extend(explicit_ids)
        author_ids.extend(inferred_ids)
        # de-dupe while preserving order
        seen = set()
        author_ids = [x for x in author_ids if not (x in seen or seen.add(x))]

        # Resolve names
        author_names = []
        for tid in author_ids:
            t = theo_by_id.get(tid)
            if t and (t.get("full_name") or t.get("name")):
                author_names.append(t.get("full_name") or t.get("name"))

        rows.append({
            "work_id": wid,
            "title": title,
            "primary_author_id": primary_id,
            "author_ids": author_ids,
            "author_names": author_names,
            "inferred_from_outlines": inferred
        })

    # Sort for stable diffs: by first author name then title/id
    rows.sort(key=lambda r: ((r["author_names"][0] if r["author_names"] else "~"), r.get("title") or "", r["work_id"]))

    OUT_FILE.parent.mkdir(parents=True, exist_ok=True)
    OUT_FILE.write_text(json.dumps(rows, ensure_ascii=False, indent=2), encoding="utf-8")
    print(f"Wrote {len(rows)} rows → {OUT_FILE}")

# if __name__ == "__main__":
#     main()

# %%
theologians = read_json(THEO_FILE, []) or []
works = read_json(WORKS_FILE, []) or []
outlines = read_jsonl(OUTLINES_L) or []
by_work = read_json(BY_WORK_FILE, []) or []
by_theologian = read_json(BY_THEOLOGIAN_FILE, []) or []

theo_by_id, name_to_id = build_theo_name_maps(theologians)
outline_counts = resolve_from_outlines(outlines)  # work_id -> Counter(tid)

# %%
work_ids_w = [w["id"] for w in works if w.get("id")]

# %%
work_ids_i = list(by_work.keys())

# %%
set(work_ids_i) == set(work_ids_w)
# Out:
# True

# %%
by_work
# Out:
# {'work_e0fde1126f74': {'referenced_in': [{'topic_id': 'top_bcdbe3b27a7f',
#     'theologian_id': 'theo_38bdde67d604',
#     'outline_id': 'out_88289cdc8036',
#     'markdown_path': 'outlines/eschatology/antichrist-and-man-of-lawlessness/gregory-k.-beale.md'}],
#   'title': '"1–2 Thessalonians" (IVP New Testament Commentary, 2003)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_cfa06cf99d84': {'referenced_in': [{'topic_id': 'top_a76905abad5a',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_fb514773a7c0',
#     'markdown_path': 'outlines/soteriology/adoption/john-owen.md'}],
#   'title': '"A Brief Declaration and Vindication of the Doctrine of the Trinity"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_9a8bad95ad9e': {'referenced_in': [{'topic_id': 'top_0e8b884aa7cb',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_d43aba4a1c96',
#     'markdown_path': 'outlines/doctrine-of-sin/nature-and-origin-of-sin/john-owen.md'}],
#   'title': '"A Brief Declaration and Vindication of the Doctrine of the Trinity" (for anthropological context)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_97263a885a5f': {'referenced_in': [{'topic_id': 'top_9b743976a17c',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_1976df3d2e79',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/visible-and-invisible-church-distinction/john-owen.md'}],
#   'title': '"A Brief Instruction in the Worship of God" (Works, vol. 15)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_36e4b8f86177': {'referenced_in': [{'topic_id': 'top_d83fcc9d8eaa',
#     'theologian_id': 'theo_06305c7dfd89',
#     'outline_id': 'out_9f440c56c492',
#     'markdown_path': 'outlines/soteriology/assurance-and-perseverance/thomas-brooks.md'}],
#   'title': '"A Cabinet of Choice Jewels"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_ab40c7e97bf4': {'referenced_in': [{'topic_id': 'top_d31900b00a67',
#     'theologian_id': 'theo_f5be9f777670',
#     'outline_id': 'out_e67e67532179',
#     'markdown_path': 'outlines/eschatology/revelation-20-and-the-millennium/kim-riddlebarger.md'}],
#   'title': '"A Case for Amillennialism: Understanding the End Times"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_19c3d7a0a1b2': {'referenced_in': [{'topic_id': 'top_25865b61d590',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_47ed0ee848a0',
#     'markdown_path': 'outlines/christology/kenosis-theories-and-critiques/richard-b.-gaffin-jr..md'}],
#   'title': '"A Cessationist View" in Are Miraculous Gifts for Today?',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_7e2f98077a97': {'referenced_in': [{'topic_id': 'top_c28e6ab43b2d',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_a225843c00e9',
#     'markdown_path': 'outlines/pneumatology/baptism-of-the-holy-spirit/richard-b.-gaffin-jr..md'}],
#   'title': '"A Cessationist View" in Are Miraculous Gifts for Today? Four Views',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_f5e3ea9b6732': {'referenced_in': [{'topic_id': 'top_a76905abad5a',
#     'theologian_id': 'theo_e84f90ea9799',
#     'outline_id': 'out_fb5a555cecaf',
#     'markdown_path': 'outlines/soteriology/adoption/anthony-n.s.-lane.md'}],
#   'title': '"A Concise History of Christian Doctrine" (2006)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_e5585550ac82': {'referenced_in': [{'topic_id': 'top_49542353d68b',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_f7dfbf6e09d6',
#     'markdown_path': 'outlines/christology/impeccability-of-christ/john-owen.md'}],
#   'title': '"A Declaration of the Glorious Mystery of the Person of Christ, God and Man"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_79881b3d7160': {'referenced_in': [{'topic_id': 'top_95f6db90a829',
#     'theologian_id': 'theo_c4bd273d811a',
#     'outline_id': 'out_675c6feef8c5',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/church-government-presbyterian-polity-offices-discipline/robert-l.-dabney.md'}],
#   'title': '"A Defence of Virginia and Through Her, of the South" (contextualizes his ecclesiology)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_affbe93e71f2': {'referenced_in': [{'topic_id': 'top_09c1f96def60',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_9c1d67b4f5a1',
#     'markdown_path': 'outlines/covenant-theology/mosaic-covenant-covenant-of-works-as-to-substance/john-owen.md'}],
#   'title': '"A Discourse Concerning Evangelical Love, Church Peace, and Unity"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_ebdcdbd57928': {'referenced_in': [{'topic_id': 'top_5f8935ddef79',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_db96a41ae627',
#     'markdown_path': 'outlines/pneumatology/person-and-deity-of-the-holy-spirit/john-owen.md'},
#    {'topic_id': 'top_f97189979aa0',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_fc5c2066b3bf',
#     'markdown_path': 'outlines/bibliology/accommodation-and-incarnational-analogy/john-owen.md'}],
#   'title': '"A Discourse Concerning the Holy Spirit"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_e9c230415f76': {'referenced_in': [{'topic_id': 'top_ffaeb0af5519',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_bfe533f585cf',
#     'markdown_path': 'outlines/soteriology/regeneration-and-effectual-calling/john-owen.md'}],
#   'title': '"A Discourse of the Work of the Holy Spirit in Prayer"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_31a5a2aeb129': {'referenced_in': [{'topic_id': 'top_59ec9b4749fe',
#     'theologian_id': 'theo_3ec37db888cb',
#     'outline_id': 'out_411c36cafc9d',
#     'markdown_path': 'outlines/theology-proper/absolute-and-relative-attributes/stephen-charnock.md'}],
#   'title': '"A Discourse on God\'s Knowledge"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_e0e44515004c': {'referenced_in': [{'topic_id': 'top_59ec9b4749fe',
#     'theologian_id': 'theo_3ec37db888cb',
#     'outline_id': 'out_411c36cafc9d',
#     'markdown_path': 'outlines/theology-proper/absolute-and-relative-attributes/stephen-charnock.md'}],
#   'title': '"A Discourse on the Eternity of God"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_7cf3786a5a66': {'referenced_in': [{'topic_id': 'top_59ec9b4749fe',
#     'theologian_id': 'theo_3ec37db888cb',
#     'outline_id': 'out_411c36cafc9d',
#     'markdown_path': 'outlines/theology-proper/absolute-and-relative-attributes/stephen-charnock.md'}],
#   'title': '"A Discourse on the Existence of God"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_cf099540637c': {'referenced_in': [{'topic_id': 'top_59ec9b4749fe',
#     'theologian_id': 'theo_3ec37db888cb',
#     'outline_id': 'out_411c36cafc9d',
#     'markdown_path': 'outlines/theology-proper/absolute-and-relative-attributes/stephen-charnock.md'}],
#   'title': '"A Discourse on the Omnipresence of God"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_ea415cd05d59': {'referenced_in': [{'topic_id': 'top_0e8b884aa7cb',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_d43aba4a1c96',
#     'markdown_path': 'outlines/doctrine-of-sin/nature-and-origin-of-sin/john-owen.md'},
#    {'topic_id': 'top_2218757d871e',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_6280e1455076',
#     'markdown_path': 'outlines/soteriology/faith-and-repentance/john-owen.md'}],
#   'title': '"A Display of Arminianism"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_31c3287fbcd1': {'referenced_in': [{'topic_id': 'top_8fe3fe69aa08',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_be90cd1bafca',
#     'markdown_path': 'outlines/covenant-theology/covenant-of-works/john-owen.md'}],
#   'title': '"A Display of Arminianism" (1643)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_2fcdf3350090': {'referenced_in': [{'topic_id': 'top_8d8955b5310f',
#     'theologian_id': 'theo_3fc45f8c5a0a',
#     'outline_id': 'out_1ff715ea2ce4',
#     'markdown_path': 'outlines/eschatology/romans-11-and-israels-future/g.c.-berkouwer.md'}],
#   'title': '"A Half Century of Theology: Movements and Motives"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_f2527d160e36': {'referenced_in': [{'topic_id': 'top_5f8935ddef79',
#     'theologian_id': 'theo_124906e9ce1f',
#     'outline_id': 'out_9db0d78cc9e5',
#     'markdown_path': 'outlines/pneumatology/person-and-deity-of-the-holy-spirit/paul-tillich.md'},
#    {'topic_id': 'top_f0438f11376d',
#     'theologian_id': 'theo_124906e9ce1f',
#     'outline_id': 'out_5dc543e3b7ec',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/filioque-and-ecumenical-creeds/paul-tillich.md'}],
#   'title': '"A History of Christian Thought"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_2c80330ddc0a': {'referenced_in': [{'topic_id': 'top_70645069130b',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_16c5b4630435',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/human-nature-psychosomatic-unity/richard-b.-gaffin-jr..md'}],
#   'title': '"A New Systematic Theology of the Christian Faith" (contributor)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_90706ee817c0': {'referenced_in': [{'topic_id': 'top_bcdbe3b27a7f',
#     'theologian_id': 'theo_38bdde67d604',
#     'outline_id': 'out_88289cdc8036',
#     'markdown_path': 'outlines/eschatology/antichrist-and-man-of-lawlessness/gregory-k.-beale.md'},
#    {'topic_id': 'top_d31900b00a67',
#     'theologian_id': 'theo_38bdde67d604',
#     'outline_id': 'out_91a58023de29',
#     'markdown_path': 'outlines/eschatology/revelation-20-and-the-millennium/gregory-k.-beale.md'}],
#   'title': '"A New Testament Biblical Theology" (2011)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_896c4b236e9e': {'referenced_in': [{'topic_id': 'top_fbddcff1d6f6',
#     'theologian_id': 'theo_38bdde67d604',
#     'outline_id': 'out_1755f0cef205',
#     'markdown_path': 'outlines/covenant-theology/klinean-covenant-theology-and-intrusion-ethics/gregory-k.-beale.md'}],
#   'title': '"A New Testament Biblical Theology: The Unfolding of the Old Testament in the New"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_ce2cb5e70ac5': {'referenced_in': [{'topic_id': 'top_f7def6611b72',
#     'theologian_id': 'theo_38bdde67d604',
#     'outline_id': 'out_bdce0160ae67',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/image-of-god/gregory-k.-beale.md'},
#    {'topic_id': 'top_fa2d2ff2ad0b',
#     'theologian_id': 'theo_38bdde67d604',
#     'outline_id': 'out_365a97d33ad4',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/vocation-dominion-and-culture-mandate/gregory-k.-beale.md'}],
#   'title': '"A New Testament Biblical Theology: The Unfolding of the Old Testament in the New" (2011)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_fc2b819a575b': {'referenced_in': [{'topic_id': 'top_14f8205e146c',
#     'theologian_id': 'theo_7e787547009a',
#     'outline_id': 'out_5f83fe18fe75',
#     'markdown_path': 'outlines/covenant-theology/federal-vision-monocovenantalism/steve-schlissel.md'}],
#   'title': '"A New Way of Seeing? A Response to the Critics of Federal Vision" (various essays and online articles)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_715a7a2e9511': {'referenced_in': [{'topic_id': 'top_4038306a84a7',
#     'theologian_id': 'theo_9c4ee1701c1d',
#     'outline_id': 'out_dabec96111b0',
#     'markdown_path': 'outlines/soteriology/federal-vision-and-justification-by-faith/douglas-wilson.md'}],
#   'title': '"A Pauline Take on the New Perspective" (Credenda/Agenda)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_99ab83135fc6': {'referenced_in': [{'topic_id': 'top_ce369aff319a',
#     'theologian_id': 'theo_1b2fdad3e936',
#     'outline_id': 'out_7290902de22e',
#     'markdown_path': 'outlines/pneumatology/pentecostalism-and-reformed-response/craig-s.-keener.md'}],
#   'title': '"A Pentecostal Approach to Reformed Theology" in The Spirit and the Church: Essays Honoring Donald Gee (2003)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_2edb60a2a960': {'referenced_in': [{'topic_id': 'top_893de9db2290',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_95d4a8e13345',
#     'markdown_path': 'outlines/bibliology/canon-and-tradition/richard-b.-gaffin-jr..md'}],
#   'title': '"A Redemptive-Historical Perspective on the New Testament Canon" (Westminster Theological Journal, 1982)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_c7683d1d9455': {'referenced_in': [{'topic_id': 'top_8d8955b5310f',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_65c9c2f8d13b',
#     'markdown_path': 'outlines/eschatology/romans-11-and-israels-future/richard-b.-gaffin-jr..md'}],
#   'title': '"A Response to \'The Israel of God\'" (in Theonomy: A Reformed Critique)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_124d8e069444': {'referenced_in': [{'topic_id': 'top_d31900b00a67',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_b97b1cf908b0',
#     'markdown_path': 'outlines/eschatology/revelation-20-and-the-millennium/richard-b.-gaffin-jr..md'}],
#   'title': '"A Response to the Premillennial View" in Three Views of the Millennium and Beyond (ed. Darrell L. Bock)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_9a64c14bca62': {'referenced_in': [{'topic_id': 'top_35f945a8703a',
#     'theologian_id': 'theo_f36e6cafc661',
#     'outline_id': 'out_2edb88b3b9a9',
#     'markdown_path': 'outlines/soteriology/justification-forensic-imputation-npp-critiques/robert-gundry.md'}],
#   'title': '"A Survey of the New Testament" (multiple editions)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_95b8702e4dec': {'referenced_in': [{'topic_id': 'top_56c2b4b21f94',
#     'theologian_id': 'theo_52c85aceaf14',
#     'outline_id': 'out_12a9b881f776',
#     'markdown_path': 'outlines/doctrine-of-sin/total-depravity-and-total-inability/jonathan-edwards.md'}],
#   'title': '"A Treatise Concerning Religious Affections"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_cb30ed2840f1': {'referenced_in': [{'topic_id': 'top_f97189979aa0',
#     'theologian_id': 'theo_89d38585bc4d',
#     'outline_id': 'out_10bf29fc82d5',
#     'markdown_path': 'outlines/bibliology/accommodation-and-incarnational-analogy/stephen-williams.md'}],
#   'title': '"Accommodation and Incarnation" in The Trustworthiness of God: Perspectives on the Nature of Scripture (2001)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_426493ac6d7c': {'referenced_in': [{'topic_id': 'top_f97189979aa0',
#     'theologian_id': 'theo_83c30089ae5d',
#     'outline_id': 'out_87bcbabd7c5b',
#     'markdown_path': 'outlines/bibliology/accommodation-and-incarnational-analogy/peter-enns.md'}],
#   'title': '"Accommodation and Incarnation: The Divine and Human in Scripture" (various essays/interviews)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_6f3c807594ed': {'referenced_in': [{'topic_id': 'top_e6fbe497576e',
#     'theologian_id': 'theo_a9d7b0a5f494',
#     'outline_id': 'out_6bb277ba9822',
#     'markdown_path': 'outlines/christology/christs-active-and-passive-obedience/john-frame.md'}],
#   'title': '"Active and Passive Obedience of Christ" (in The Collected Shorter Theological Writings)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_d42b9c8f49f5': {'referenced_in': [{'topic_id': 'top_8fe3fe69aa08',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_441d82bda031',
#     'markdown_path': 'outlines/covenant-theology/covenant-of-works/richard-b.-gaffin-jr..md'}],
#   'title': '"Adam and Israel: The Covenant of Works in Paul" (in Covenant, Justification, and Pastoral Ministry, ed. Waters)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_eb86fbc18223': {'referenced_in': [{'topic_id': 'top_05d674cd94ab',
#     'theologian_id': 'theo_d202f60f304c',
#     'outline_id': 'out_34c77854001b',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/historicity-and-federal-headship-of-adam/vern-poythress.md'}],
#   'title': '"Adam Versus Claims from Genetics" (Westminster Theological Journal, 2013)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_e89d163c5d93': {'referenced_in': [{'topic_id': 'top_0e8b884aa7cb',
#     'theologian_id': 'theo_452e8ff3c243',
#     'outline_id': 'out_f473231e0657',
#     'markdown_path': 'outlines/doctrine-of-sin/nature-and-origin-of-sin/richard-gaffin.md'}],
#   'title': '"Adam, Christ, and Covenant" (in "Biblical Hermeneutics: Five Views")',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_0ff513f9b562': {'referenced_in': [{'topic_id': 'top_5ee2943a1c10',
#     'theologian_id': 'theo_4957eb6ae45c',
#     'outline_id': 'out_ae7226fe9034',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/church-and-kingdom/martin-luther.md'},
#    {'topic_id': 'top_98b921136462',
#     'theologian_id': 'theo_4957eb6ae45c',
#     'outline_id': 'out_8e4cb13a0d75',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/church-and-state-relations/martin-luther.md'}],
#   'title': '"Address to the Christian Nobility of the German Nation" (1520)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_d76b8ccc59b3': {'referenced_in': [{'topic_id': 'top_a76905abad5a',
#     'theologian_id': 'theo_d202f60f304c',
#     'outline_id': 'out_967d3e1f563c',
#     'markdown_path': 'outlines/soteriology/adoption/vern-poythress.md'}],
#   'title': '"Adoption" entry in New Dictionary of Theology (contributor)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_47a46961ace4': {'referenced_in': [{'topic_id': 'top_a76905abad5a',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_298382918f03',
#     'markdown_path': 'outlines/soteriology/adoption/benjamin-b.-warfield.md'}],
#   'title': '"Adoption" in *Biblical and Theological Studies* (Princeton Theological Seminary, 1912)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_da57db41accf': {'referenced_in': [{'topic_id': 'top_dbb4a423f256',
#     'theologian_id': 'theo_14fdb72b1032',
#     'outline_id': 'out_9770fd1dfbb0',
#     'markdown_path': 'outlines/doctrine-of-sin/the-fall-and-its-consequences/henri-blocher.md'}],
#   'title': '"Agnus Victor: The Atonement as Victory and Vicarious Punishment" (in What Does It Mean to Be Saved?)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_08f1b20cde1d': {'referenced_in': [{'topic_id': 'top_99edd6956d50',
#     'theologian_id': 'theo_776c109f14d3',
#     'outline_id': 'out_d017e2334bb3',
#     'markdown_path': 'outlines/eschatology/individual-and-cosmic-eschatology/anthony-a.-hoekema.md'},
#    {'topic_id': 'top_bcdbe3b27a7f',
#     'theologian_id': 'theo_776c109f14d3',
#     'outline_id': 'out_4393f2be0110',
#     'markdown_path': 'outlines/eschatology/antichrist-and-man-of-lawlessness/anthony-a.-hoekema.md'},
#    {'topic_id': 'top_cfca4bcdf259',
#     'theologian_id': 'theo_776c109f14d3',
#     'outline_id': 'out_00457be3f709',
#     'markdown_path': 'outlines/eschatology/millennial-views/anthony-a.-hoekema.md'},
#    {'topic_id': 'top_d31900b00a67',
#     'theologian_id': 'theo_776c109f14d3',
#     'outline_id': 'out_b6f92d93291d',
#     'markdown_path': 'outlines/eschatology/revelation-20-and-the-millennium/anthony-a.-hoekema.md'}],
#   'title': '"Amillennialism" in The Meaning of the Millennium: Four Views (1977)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_de0632ef9fc8': {'referenced_in': [{'topic_id': 'top_63d8723083d3',
#     'theologian_id': 'theo_776c109f14d3',
#     'outline_id': 'out_2d8bc0e20b2e',
#     'markdown_path': 'outlines/eschatology/realized-vs-future-eschatology/anthony-a.-hoekema.md'}],
#   'title': '"Amillennialism" in The Meaning of the Millennium: Four Views (ed. Robert G. Clouse)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_27f6a7b10011': {'referenced_in': [{'topic_id': 'top_cfca4bcdf259',
#     'theologian_id': 'theo_f5be9f777670',
#     'outline_id': 'out_2f3fd28e169c',
#     'markdown_path': 'outlines/eschatology/millennial-views/kim-riddlebarger.md'}],
#   'title': '"Amillennialism" in Three Views on the Millennium and Beyond (1999, ed. Darrell L. Bock)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_83f3222390a0': {'referenced_in': [{'topic_id': 'top_8d8955b5310f',
#     'theologian_id': 'theo_abe64b308111',
#     'outline_id': 'out_8adacf1b87b7',
#     'markdown_path': 'outlines/eschatology/romans-11-and-israels-future/michael-f.-bird.md'}],
#   'title': '"An Anomalous Jew: Paul among Jews, Greeks, and Romans" (2016)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_4418b7fac5ba': {'referenced_in': [{'topic_id': 'top_a76905abad5a',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_fb514773a7c0',
#     'markdown_path': 'outlines/soteriology/adoption/john-owen.md'}],
#   'title': '"An Exposition of the Epistle to the Hebrews"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_e027c41b555d': {'referenced_in': [{'topic_id': 'top_8fe3fe69aa08',
#     'theologian_id': 'theo_01884231e7c8',
#     'outline_id': 'out_be90cd1bafca',
#     'markdown_path': 'outlines/covenant-theology/covenant-of-works/john-owen.md'}],
#   'title': '"An Exposition of the Epistle to the Hebrews" (especially Vol. 1)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_9243638e1fb9': {'referenced_in': [{'topic_id': 'top_49542353d68b',
#     'theologian_id': 'theo_ff69d567b651',
#     'outline_id': 'out_bb4e1286a88b',
#     'markdown_path': 'outlines/christology/impeccability-of-christ/cornelius-van-til.md'},
#    {'topic_id': 'top_93f7217bd068',
#     'theologian_id': 'theo_ff69d567b651',
#     'outline_id': 'out_9b4c1dcf3316',
#     'markdown_path': 'outlines/christology/pactum-salutis-and-christ-as-covenant-head/cornelius-van-til.md'}],
#   'title': '"An Introduction to Systematic Theology"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_e18c2deeba13': {'referenced_in': [{'topic_id': 'top_1ae090f64d92',
#     'theologian_id': 'theo_ff69d567b651',
#     'outline_id': 'out_91183e0b1377',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/van-tils-one-person-language-and-its-critique/cornelius-van-til.md'}],
#   'title': '"An Introduction to Systematic Theology" (especially chapters on the doctrine of God)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_de59be255f98': {'referenced_in': [{'topic_id': 'top_3e356f12a7e8',
#     'theologian_id': 'theo_a71d06ea1b9a',
#     'outline_id': 'out_9df067102293',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/days-of-creation/bruce-k.-waltke.md'}],
#   'title': '"An Old Testament Theology: An Exegetical, Canonical, and Thematic Approach" (2007)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_c0d218db057f': {'referenced_in': [{'topic_id': 'top_51340b70fbc9',
#     'theologian_id': 'theo_c2678a5b805f',
#     'outline_id': 'out_1df15ec7334e',
#     'markdown_path': 'outlines/bibliology/analogia-entis-vs-analogia-fidei/erich-przywara.md'}],
#   'title': '"Analogia Entis: Metaphysics—Original Structure and Universal Rhythm" (1932; English trans. 2014)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_67c1f18cacca': {'referenced_in': [{'topic_id': 'top_e9f9e46d28c1',
#     'theologian_id': 'theo_2498929fd72b',
#     'outline_id': 'out_c7853b91686b',
#     'markdown_path': 'outlines/christology/atonement-necessity-extent-and-theories/hugo-grotius.md'}],
#   'title': '"Annotations on the New Testament"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_db7d7274f0b3': {'referenced_in': [{'topic_id': 'top_9b743976a17c',
#     'theologian_id': 'theo_58387045c6b4',
#     'outline_id': 'out_ed342582eae2',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/visible-and-invisible-church-distinction/karl-rahner.md'}],
#   'title': '"Anonymous Christians" (essay in Theological Investigations, vol. 6)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_9659cec5fe7f': {'referenced_in': [{'topic_id': 'top_05d674cd94ab',
#     'theologian_id': 'theo_fdb0163ae082',
#     'outline_id': 'out_8eea416a254d',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/historicity-and-federal-headship-of-adam/wolfhart-pannenberg.md'},
#    {'topic_id': 'top_75286856d56e',
#     'theologian_id': 'theo_fdb0163ae082',
#     'outline_id': 'out_697fafca28bc',
#     'markdown_path': 'outlines/pneumatology/spiritual-gifts-and-sanctification/wolfhart-pannenberg.md'},
#    {'topic_id': 'top_858357de003a',
#     'theologian_id': 'theo_fdb0163ae082',
#     'outline_id': 'out_53f72846aac4',
#     'markdown_path': 'outlines/soteriology/union-with-christ/wolfhart-pannenberg.md'},
#    {'topic_id': 'top_a76905abad5a',
#     'theologian_id': 'theo_fdb0163ae082',
#     'outline_id': 'out_866646bc00aa',
#     'markdown_path': 'outlines/soteriology/adoption/wolfhart-pannenberg.md'},
#    {'topic_id': 'top_dfb81633226f',
#     'theologian_id': 'theo_fdb0163ae082',
#     'outline_id': 'out_5f6e28209a15',
#     'markdown_path': 'outlines/doctrine-of-sin/sin-and-free-will/wolfhart-pannenberg.md'}],
#   'title': '"Anthropology in Theological Perspective"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_785cf28479af': {'referenced_in': [{'topic_id': 'top_b9288d484351',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_08cf321c5a9d',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/trichotomy-vs-dichotomy/richard-b.-gaffin-jr..md'}],
#   'title': '"Anthropology" in New Dictionary of Theology (ed. Sinclair Ferguson, David Wright)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_6d8576b35c0a': {'referenced_in': [{'topic_id': 'top_751b5cc38691',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_941424192e7e',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/traducianism-vs-creationism/richard-b.-gaffin-jr..md'}],
#   'title': '"Anthropology" lectures (Westminster Theological Seminary)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_050c48ea4c59': {'referenced_in': [{'topic_id': 'top_bcdbe3b27a7f',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_a7eaecf3a3eb',
#     'markdown_path': 'outlines/eschatology/antichrist-and-man-of-lawlessness/benjamin-b.-warfield.md'}],
#   'title': '"Antichrist" in International Standard Bible Encyclopedia',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_cee2c5d10972': {'referenced_in': [{'topic_id': 'top_92604f919605',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_ea4ffdacb975',
#     'markdown_path': 'outlines/pneumatology/continuationism-vs-cessationism/richard-b.-gaffin-jr..md'}],
#   'title': '"Are Miraculous Gifts for Today? Four Views" (contributor, 1996)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_94634b31ad20': {'referenced_in': [{'topic_id': 'top_ce369aff319a',
#     'theologian_id': 'theo_7b3bc848e42f',
#     'outline_id': 'out_050cdacf6bd6',
#     'markdown_path': 'outlines/pneumatology/pentecostalism-and-reformed-response/o.-palmer-robertson.md'}],
#   'title': '"Are Miraculous Gifts for Today?" (contributor to edited volumes)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_b56f573df8be': {'referenced_in': [{'topic_id': 'top_92604f919605',
#     'theologian_id': 'theo_7b3bc848e42f',
#     'outline_id': 'out_ccf08bc7a621',
#     'markdown_path': 'outlines/pneumatology/continuationism-vs-cessationism/o.-palmer-robertson.md'}],
#   'title': '"Are Miraculous Gifts for Today?" (contributor, edited by Wayne Grudem)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_f2692796778f': {'referenced_in': [{'topic_id': 'top_d83fcc9d8eaa',
#     'theologian_id': 'theo_4063565914eb',
#     'outline_id': 'out_9edac1bdebde',
#     'markdown_path': 'outlines/soteriology/assurance-and-perseverance/sinclair-b.-ferguson.md'}],
#   'title': '"Assurance" (in New Dictionary of Theology, eds. Sinclair B. Ferguson and David F. Wright)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_896ada4a0f77': {'referenced_in': [{'topic_id': 'top_d83fcc9d8eaa',
#     'theologian_id': 'theo_a9d7b0a5f494',
#     'outline_id': 'out_ddf33e4f48f0',
#     'markdown_path': 'outlines/soteriology/assurance-and-perseverance/john-frame.md'}],
#   'title': '"Assurance" in The Collected Shorter Writings of John Frame, Vol. 1 (2012)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_7d953b4322e3': {'referenced_in': [{'topic_id': 'top_e9f9e46d28c1',
#     'theologian_id': 'theo_d202f60f304c',
#     'outline_id': 'out_1e737a048866',
#     'markdown_path': 'outlines/christology/atonement-necessity-extent-and-theories/vern-poythress.md'}],
#   'title': '"Atonement in the Mosaic Law" (in The Glory of the Atonement, eds. Hill & Letham, 2004)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_06a4a062fbdc': {'referenced_in': [{'topic_id': 'top_ef56eeea43c3',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_74399b8be870',
#     'markdown_path': 'outlines/theology-proper/divine-decrees-election-and-reprobation/richard-b.-gaffin-jr..md'}],
#   'title': '"Atonement in the Pauline Corpus" (in The Glory of the Atonement, eds. Hill & Letham)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_85b79d7d0619': {'referenced_in': [{'topic_id': 'top_31f6d4fc5cf2',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_94665a0bf48f',
#     'markdown_path': 'outlines/doctrine-of-sin/pelagianism-semi-pelagianism-and-augustinianism/benjamin-b.-warfield.md'}],
#   'title': '"Augustine and His Work" (in *Calvin and Augustine*)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_1aeb119e85c8': {'referenced_in': [{'topic_id': 'top_dbb4a423f256',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_73beb6cec1dd',
#     'markdown_path': 'outlines/doctrine-of-sin/the-fall-and-its-consequences/benjamin-b.-warfield.md'}],
#   'title': '"Augustine and the Pelagian Controversy"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_f8f077345218': {'referenced_in': [{'topic_id': 'top_0bb341578fd1',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_af434d20c891',
#     'markdown_path': 'outlines/theology-proper/divine-foreknowledge-providence-and-the-problem-of-evil/benjamin-b.-warfield.md'}],
#   'title': '"Augustine and the Pelagian Controversy" in The Works of Benjamin B. Warfield, Vol. 4',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_cc9daa0ee92c': {'referenced_in': [{'topic_id': 'top_c28e6ab43b2d',
#     'theologian_id': 'theo_4063565914eb',
#     'outline_id': 'out_34747ff3d23d',
#     'markdown_path': 'outlines/pneumatology/baptism-of-the-holy-spirit/sinclair-b.-ferguson.md'}],
#   'title': '"Baptism and Fullness: The Work of the Holy Spirit Today" (in edited volumes)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_6500d19ed3f7': {'referenced_in': [{'topic_id': 'top_6cf266588fcf',
#     'theologian_id': 'theo_e85049ceff8c',
#     'outline_id': 'out_e7e700e2104f',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/baptism-mode-infant-vs-believers-efficacy/gregg-strawbridge.md'}],
#   'title': '"Baptism and the Covenant of Grace" (conference lectures)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_490c50245317': {'referenced_in': [{'topic_id': 'top_ac07f9cc897d',
#     'theologian_id': 'theo_36e05d3dea37',
#     'outline_id': 'out_fdd3d498f319',
#     'markdown_path': 'outlines/covenant-theology/biblical-covenants/stephen-j.-wellum.md'}],
#   'title': '"Baptism and the Relationship Between the Covenants" (in Believer’s Baptism: Sign of the New Covenant in Christ)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_82436d620a4f': {'referenced_in': [{'topic_id': 'top_60a07ef7da83',
#     'theologian_id': 'theo_36e05d3dea37',
#     'outline_id': 'out_c270a787c006',
#     'markdown_path': 'outlines/covenant-theology/dispensationalism-and-progressive-covenantalism/stephen-j.-wellum.md'}],
#   'title': '"Baptism and the Relationship between the Covenants" in Believer’s Baptism: Sign of the New Covenant in Christ',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_9d2e70f3852e': {'referenced_in': [{'topic_id': 'top_fbddcff1d6f6',
#     'theologian_id': 'theo_36e05d3dea37',
#     'outline_id': 'out_b74280890f69',
#     'markdown_path': 'outlines/covenant-theology/klinean-covenant-theology-and-intrusion-ethics/stephen-j.-wellum.md'}],
#   'title': '"Baptism and the Relationship Between the Covenants" in Believer’s Baptism: Sign of the New Covenant in Christ (2007)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_5d7727455afa': {'referenced_in': [{'topic_id': 'top_6cf266588fcf',
#     'theologian_id': 'theo_fdb0163ae082',
#     'outline_id': 'out_21f992496d7f',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/baptism-mode-infant-vs-believers-efficacy/wolfhart-pannenberg.md'}],
#   'title': '"Baptism and the Unity of the Church" (in Basic Questions in Theology, Vol. 2)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_5b9145a4a365': {'referenced_in': [{'topic_id': 'top_6cf266588fcf',
#     'theologian_id': 'theo_09edae13e8c2',
#     'outline_id': 'out_fd7df0ac182f',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/baptism-mode-infant-vs-believers-efficacy/jrgen-moltmann.md'}],
#   'title': '"Baptism and the Unity of the Church" (in various ecumenical dialogues)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_6f76a44f729f': {'referenced_in': [{'topic_id': 'top_c28e6ab43b2d',
#     'theologian_id': 'theo_97952d3f743d',
#     'outline_id': 'out_922b7071e272',
#     'markdown_path': 'outlines/pneumatology/baptism-of-the-holy-spirit/gordon-d.-fee.md'}],
#   'title': '"Baptism in the Holy Spirit: The Issue of Separability and Subsequence" (in Pneuma, 1985)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_9445e89dafb6': {'referenced_in': [{'topic_id': 'top_6cf266588fcf',
#     'theologian_id': 'theo_a9d7b0a5f494',
#     'outline_id': 'out_ac50f8f88c2d',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/baptism-mode-infant-vs-believers-efficacy/john-frame.md'}],
#   'title': '"Baptism in the Orthodox Presbyterian Church" (OPC pamphlet)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_daf1da03ddff': {'referenced_in': [{'topic_id': 'top_05d674cd94ab',
#     'theologian_id': 'theo_fdb0163ae082',
#     'outline_id': 'out_8eea416a254d',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/historicity-and-federal-headship-of-adam/wolfhart-pannenberg.md'},
#    {'topic_id': 'top_0bb341578fd1',
#     'theologian_id': 'theo_fdb0163ae082',
#     'outline_id': 'out_61e4f40b88fc',
#     'markdown_path': 'outlines/theology-proper/divine-foreknowledge-providence-and-the-problem-of-evil/wolfhart-pannenberg.md'}],
#   'title': '"Basic Questions in Theology," Vol. 2',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_65aac9656562': {'referenced_in': [{'topic_id': 'top_dfb81633226f',
#     'theologian_id': 'theo_fdb0163ae082',
#     'outline_id': 'out_5f6e28209a15',
#     'markdown_path': 'outlines/doctrine-of-sin/sin-and-free-will/wolfhart-pannenberg.md'}],
#   'title': '"Basic Questions in Theology," Volumes 1–3',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_4f0c024fdf27': {'referenced_in': [{'topic_id': 'top_ec2857b18ab9',
#     'theologian_id': 'theo_504fab07ab2f',
#     'outline_id': 'out_e76ab3387081',
#     'markdown_path': 'outlines/soteriology/common-grace-and-preparatory-grace/john-bolt.md'}],
#   'title': '"Bavinck on the Christian Life: Following Jesus in Faithful Service" (2015)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_2adaa54c9026': {'referenced_in': [{'topic_id': 'top_4562bb8d7d9e',
#     'theologian_id': 'theo_7ab423f6dffc',
#     'outline_id': 'out_016152e34feb',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/science-and-scripture-genesis-1-11/meredith-g.-kline.md'}],
#   'title': '"Because It Had Not Rained" (Westminster Theological Journal, 1958)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_e3509b6640bd': {'referenced_in': [{'topic_id': 'top_3e356f12a7e8',
#     'theologian_id': 'theo_7ab423f6dffc',
#     'outline_id': 'out_9b9254e0688c',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/days-of-creation/meredith-g.-kline.md'}],
#   'title': '"Because It Had Not Rained: A Note on Genesis 2:5–6 and Genesis 1:1–2:3" (Westminster Theological Journal, 1958)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_8fa92fba4285': {'referenced_in': [{'topic_id': 'top_5cfabb0ffc0a',
#     'theologian_id': 'theo_7ab423f6dffc',
#     'outline_id': 'out_f491e273777a',
#     'markdown_path': 'outlines/bibliology/inspiration-and-inerrancy/meredith-g.-kline.md'}],
#   'title': '"Because It Is Written" (Westminster Theological Journal article)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_1bd086212c73': {'referenced_in': [{'topic_id': 'top_bf683e100ebe',
#     'theologian_id': 'theo_b1eabb8e768a',
#     'outline_id': 'out_4ed7d5d51ca6',
#     'markdown_path': 'outlines/bibliology/epistemology-and-the-knowledge-of-god/jean-luc-marion.md'}],
#   'title': '"Being Given: Toward a Phenomenology of Givenness"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_714f4aa1cdba': {'referenced_in': [{'topic_id': 'top_4562bb8d7d9e',
#     'theologian_id': 'theo_36130d033063',
#     'outline_id': 'out_a474921faf01',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/science-and-scripture-genesis-1-11/denis-o.-lamoureux.md'}],
#   'title': '"Beyond the \'Evolution\' vs. \'Creation\' Debate" (Perspectives on Science and Christian Faith, 2003)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_28aa97ed3362': {'referenced_in': [{'topic_id': 'top_4d8a12d40876',
#     'theologian_id': 'theo_82f275e77587',
#     'outline_id': 'out_288fd1969e2f',
#     'markdown_path': 'outlines/eschatology/new-heavens-and-new-earth/richard-j.-bauckham.md'}],
#   'title': '"Bible and Ecology: Rediscovering the Community of Creation" (2010)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_7b891d07b964': {'referenced_in': [{'topic_id': 'top_5d2d02d30dbf',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_68aa622d1138',
#     'markdown_path': 'outlines/christology/munus-triplex/benjamin-b.-warfield.md'}],
#   'title': '"Biblical and Theological Studies" (esp. essays on Christology)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_df9af36c3c6e': {'referenced_in': [{'topic_id': 'top_fa2d2ff2ad0b',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_4df26066c592',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/vocation-dominion-and-culture-mandate/benjamin-b.-warfield.md'}],
#   'title': '"Biblical and Theological Studies" (especially essays on creation and the image of God)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_9d87bba47c9a': {'referenced_in': [{'topic_id': 'top_a6ab38e08ca3',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_f83918bf4a62',
#     'markdown_path': 'outlines/theology-proper/simplicity-aseity-immutability-impassibility/benjamin-b.-warfield.md'}],
#   'title': '"Biblical and Theological Studies" (especially essays on the doctrine of God)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_814c78a1869e': {'referenced_in': [{'topic_id': 'top_b6fa04d6ef6b',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_037d590d9058',
#     'markdown_path': 'outlines/covenant-theology/covenant-of-redemption/benjamin-b.-warfield.md'}],
#   'title': '"Biblical and Theological Studies" (posthumous collection)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_ccc4678e675f': {'referenced_in': [{'topic_id': 'top_06a687ae0e11',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_6194008e0cb8',
#     'markdown_path': 'outlines/christology/eternal-sonship-and-incarnation/benjamin-b.-warfield.md'}],
#   'title': '"Biblical and Theological Studies" (various essays)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_ffa1d70d07bf': {'referenced_in': [{'topic_id': 'top_70645069130b',
#     'theologian_id': 'theo_ce6917d33274',
#     'outline_id': 'out_eeafadb821ae',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/human-nature-psychosomatic-unity/john-cooper.md'}],
#   'title': '"Biblical Anthropology and the Body-Soul Problem" in In Search of the Soul: Four Views of the Mind-Body Problem (2005)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_c562f07aa83d': {'referenced_in': [{'topic_id': 'top_8d8955b5310f',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_cb1546ad14b7',
#     'markdown_path': 'outlines/eschatology/romans-11-and-israels-future/benjamin-b.-warfield.md'}],
#   'title': '"Biblical Doctrines"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_c034beb6352d': {'referenced_in': [{'topic_id': 'top_842a4a7549be',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_f0fc48550502',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/ontological-vs-economic-trinity/benjamin-b.-warfield.md'}],
#   'title': '"Biblical Doctrines" (especially the essay "The Biblical Doctrine of the Trinity")',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_4fc9f613be57': {'referenced_in': [{'topic_id': 'top_2faa3c3f1f60',
#     'theologian_id': 'theo_8173f20b2141',
#     'outline_id': 'out_b5bb5e87e37a',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/eternal-functional-subordination-debates/wayne-grudem.md'}],
#   'title': '"Biblical Evidence for the Eternal Submission of the Son to the Father" (Journal for Biblical Manhood and Womanhood, 2001)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_9ccb1887d0b5': {'referenced_in': [{'topic_id': 'top_2faa3c3f1f60',
#     'theologian_id': 'theo_a9d7b0a5f494',
#     'outline_id': 'out_e664a2f529e6',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/eternal-functional-subordination-debates/john-frame.md'}],
#   'title': '"Biblical Evidence for the Eternal Submission of the Son to the Father" (various essays and lectures)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_9ed5514f15eb': {'referenced_in': [{'topic_id': 'top_14f8205e146c',
#     'theologian_id': 'theo_f41d8692a02b',
#     'outline_id': 'out_c24d128922d3',
#     'markdown_path': 'outlines/covenant-theology/federal-vision-monocovenantalism/james-b.-jordan.md'}],
#   'title': '"Biblical Horizons" newsletter (various issues addressing Federal Vision and covenant theology)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_614ff9f3c5e6': {'referenced_in': [{'topic_id': 'top_98b921136462',
#     'theologian_id': 'theo_d202f60f304c',
#     'outline_id': 'out_f708d19bdee2',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/church-and-state-relations/vern-poythress.md'}],
#   'title': '"Biblical Principles of Government" (Westminster Theological Journal, 1994)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_199e5d657aa5': {'referenced_in': [{'topic_id': 'top_ae768ef7125f',
#     'theologian_id': 'theo_d202f60f304c',
#     'outline_id': 'out_8a5d9ea6f405',
#     'markdown_path': 'outlines/soteriology/historia-salutis-vs-ordo-salutis/vern-poythress.md'}],
#   'title': '"Biblical Theology and Multiperspectivalism" (Westminster Theological Journal)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_5107889eee99': {'referenced_in': [{'topic_id': 'top_5aeece297aca',
#     'theologian_id': 'theo_a9d7b0a5f494',
#     'outline_id': 'out_14e737d81427',
#     'markdown_path': 'outlines/bibliology/biblical-theology-vs-systematic-theology/john-frame.md'}],
#   'title': '"Biblical Theology and Systematic Theology as Disciplines of the Word" (in Theological Studies and the Church, 1976)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_acf47cf59f65': {'referenced_in': [{'topic_id': 'top_51340b70fbc9',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_e7fbe36ab451',
#     'markdown_path': 'outlines/bibliology/analogia-entis-vs-analogia-fidei/richard-b.-gaffin-jr..md'}],
#   'title': '"Biblical Theology and Systematic Theology" in New Dictionary of Biblical Theology',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_3676cc0483fc': {'referenced_in': [{'topic_id': 'top_ead51bf0fc19',
#     'theologian_id': 'theo_82f275e77587',
#     'outline_id': 'out_97f9f47dba9d',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/biblical-basis-ot-and-nt-revelation-of-the-trinity/richard-j.-bauckham.md'}],
#   'title': '"Biblical Theology and the Problems of Monotheism" (in The Jewish World Around the New Testament)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_3e157ad8c4b8': {'referenced_in': [{'topic_id': 'top_64e2f64bb983',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_a8f56d422d41',
#     'markdown_path': 'outlines/soteriology/good-works-and-merit-in-the-covenant-of-grace/richard-b.-gaffin-jr..md'}],
#   'title': '"Biblical Theology and the Westminster Standards" (in *The Westminster Theological Journal*)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_f85b319c4bcf': {'referenced_in': [{'topic_id': 'top_06a687ae0e11',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_0127efb8d68e',
#     'markdown_path': 'outlines/christology/eternal-sonship-and-incarnation/richard-b.-gaffin-jr..md'},
#    {'topic_id': 'top_3cfc6df9b029',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_c521b1f95b13',
#     'markdown_path': 'outlines/doctrine-of-sin/guilt-pollution-and-death/richard-b.-gaffin-jr..md'},
#    {'topic_id': 'top_7e8a2612951f',
#     'theologian_id': 'theo_452e8ff3c243',
#     'outline_id': 'out_762ff519f840',
#     'markdown_path': 'outlines/doctrine-of-sin/original-sin-and-imputation/richard-gaffin.md'},
#    {'topic_id': 'top_8fe3fe69aa08',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_441d82bda031',
#     'markdown_path': 'outlines/covenant-theology/covenant-of-works/richard-b.-gaffin-jr..md'},
#    {'topic_id': 'top_ac07f9cc897d',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_5d3d3df47b73',
#     'markdown_path': 'outlines/covenant-theology/biblical-covenants/richard-b.-gaffin-jr..md'},
# ...
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_b9aa1592d7ee': {'referenced_in': [{'topic_id': 'top_de5883e6a1c5',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_f9660ee4fbc3',
#     'markdown_path': 'outlines/soteriology/sanctification-definitive-and-progressive/benjamin-b.-warfield.md'}],
#   'title': '"The Biblical Doctrine of Sanctification" (in Selected Shorter Writings)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_2a3d87b0df8a': {'referenced_in': [{'topic_id': 'top_a08c7eb01fa2',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_65102cdd8567',
#     'markdown_path': 'outlines/christology/christ-in-ot-and-nt/benjamin-b.-warfield.md'}],
#   'title': '"The Biblical Doctrine of the Trinity"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_fb996b434878': {'referenced_in': [{'topic_id': 'top_2faa3c3f1f60',
#     'theologian_id': 'theo_991f5a107a5c',
#     'outline_id': 'out_c04f17113ac6',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/eternal-functional-subordination-debates/charles-hodge.md'}],
#   'title': '"The Biblical Doctrine of the Trinity" (Biblical Repertory and Princeton Review, 1840)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_c339bffdc9f2': {'referenced_in': [{'topic_id': 'top_2be42d1a0a05',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_3671b89d47f0',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/one-holy-catholic-apostolic-church/benjamin-b.-warfield.md'}],
#   'title': '"The Biblical Doctrine of the Trinity" (for ecclesiological implications)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_15777f1f1cea': {'referenced_in': [{'topic_id': 'top_1ae090f64d92',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_d53a53151210',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/van-tils-one-person-language-and-its-critique/benjamin-b.-warfield.md'},
#    {'topic_id': 'top_2faa3c3f1f60',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_cd254f983d18',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/eternal-functional-subordination-debates/benjamin-b.-warfield.md'},
#    {'topic_id': 'top_4a04b146066a',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_0a232414c29a',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/rahners-rule-and-barths-reformulation/benjamin-b.-warfield.md'},
#    {'topic_id': 'top_ead51bf0fc19',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_e86896952058',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/biblical-basis-ot-and-nt-revelation-of-the-trinity/benjamin-b.-warfield.md'},
#    {'topic_id': 'top_f0438f11376d',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_b2ea0ca082db',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/filioque-and-ecumenical-creeds/benjamin-b.-warfield.md'}],
#   'title': '"The Biblical Doctrine of the Trinity" (in Biblical and Theological Studies)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_c7e956776414': {'referenced_in': [{'topic_id': 'top_5f8935ddef79',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_0ea847da0495',
#     'markdown_path': 'outlines/pneumatology/person-and-deity-of-the-holy-spirit/benjamin-b.-warfield.md'},
#    {'topic_id': 'top_a0bc1cbe3382',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_afe3ac224b65',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/eternal-generation-and-spiration/benjamin-b.-warfield.md'}],
#   'title': '"The Biblical Doctrine of the Trinity" (in Biblical Doctrines)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_48c76d54674e': {'referenced_in': [{'topic_id': 'top_a0bc1cbe3382',
#     'theologian_id': 'theo_991f5a107a5c',
#     'outline_id': 'out_c6d1fc6e2fb1',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/eternal-generation-and-spiration/charles-hodge.md'}],
#   'title': '"The Biblical Doctrine of the Trinity" (Princeton Review article)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_3ccba4186bec': {'referenced_in': [{'topic_id': 'top_5aeece297aca',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_26e4d0e5322c',
#     'markdown_path': 'outlines/bibliology/biblical-theology-vs-systematic-theology/benjamin-b.-warfield.md'},
#    {'topic_id': 'top_acae6fb0ac6d',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_506395b2d8ec',
#     'markdown_path': 'outlines/covenant-theology/typology-and-fulfillment/benjamin-b.-warfield.md'},
#    {'topic_id': 'top_f97189979aa0',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_933872ae179d',
#     'markdown_path': 'outlines/bibliology/accommodation-and-incarnational-analogy/benjamin-b.-warfield.md'}],
#   'title': '"The Biblical Idea of Revelation"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_ea30f48ec7fc': {'referenced_in': [{'topic_id': 'top_8c081315e830',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_44eb99be2fab',
#     'markdown_path': 'outlines/theology-proper/existence-and-knowability-of-god/benjamin-b.-warfield.md'}],
#   'title': '"The Biblical Idea of Revelation" (in The Works of Benjamin B. Warfield, vol. 1)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_1a25a790ac0a': {'referenced_in': [{'topic_id': 'top_0bb341578fd1',
#     'theologian_id': 'theo_0fb2dd147a7b',
#     'outline_id': 'out_af434d20c891',
#     'markdown_path': 'outlines/theology-proper/divine-foreknowledge-providence-and-the-problem-of-evil/benjamin-b.-warfield.md'}],
#   'title': '"The Biblical Idea of Revelation" in The Works of Benjamin B. Warfield, Vol. 1',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_56566af7ec12': {'referenced_in': [{'topic_id': 'top_dfb81633226f',
#     'theologian_id': 'theo_0a257bf889f6',
#     'outline_id': 'out_bc7b68f02a2d',
#     'markdown_path': 'outlines/doctrine-of-sin/sin-and-free-will/richard-a.-muller.md'}],
#   'title': '"The Bondage and Liberation of the Will in the Reformed Tradition" (in After Calvin)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_2043d9ed0444': {'referenced_in': [{'topic_id': 'top_d31900b00a67',
#     'theologian_id': 'theo_0967b706d70a',
#     'outline_id': 'out_fcc7e0ce9b39',
#     'markdown_path': 'outlines/eschatology/revelation-20-and-the-millennium/john-murray.md'}],
#   'title': '"The Book of Revelation" (in Collected Writings of John Murray, Vol. 2)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_8dbf824baaf5': {'referenced_in': [{'topic_id': 'top_bcdbe3b27a7f',
#     'theologian_id': 'theo_38bdde67d604',
#     'outline_id': 'out_88289cdc8036',
#     'markdown_path': 'outlines/eschatology/antichrist-and-man-of-lawlessness/gregory-k.-beale.md'},
#    {'topic_id': 'top_d31900b00a67',
#     'theologian_id': 'theo_38bdde67d604',
#     'outline_id': 'out_91a58023de29',
#     'markdown_path': 'outlines/eschatology/revelation-20-and-the-millennium/gregory-k.-beale.md'}],
#   'title': '"The Book of Revelation" (New International Greek Testament Commentary, 1999)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_3992045efa75': {'referenced_in': [{'topic_id': 'top_fbddcff1d6f6',
#     'theologian_id': 'theo_38bdde67d604',
#     'outline_id': 'out_1755f0cef205',
#     'markdown_path': 'outlines/covenant-theology/klinean-covenant-theology-and-intrusion-ethics/gregory-k.-beale.md'}],
#   'title': '"The Book of Revelation" (NIGTC)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_b756ea787c7f': {'referenced_in': [{'topic_id': 'top_f7def6611b72',
#     'theologian_id': 'theo_38bdde67d604',
#     'outline_id': 'out_bdce0160ae67',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/image-of-god/gregory-k.-beale.md'},
#    {'topic_id': 'top_fa2d2ff2ad0b',
#     'theologian_id': 'theo_38bdde67d604',
#     'outline_id': 'out_365a97d33ad4',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/vocation-dominion-and-culture-mandate/gregory-k.-beale.md'}],
#   'title': '"The Book of Revelation" (NIGTC, 1999)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_7afac90f26a6': {'referenced_in': [{'topic_id': 'top_64e2f64bb983',
#     'theologian_id': 'theo_8b3fc578947f',
#     'outline_id': 'out_c70f85797427',
#     'markdown_path': 'outlines/soteriology/good-works-and-merit-in-the-covenant-of-grace/andrew-fuller.md'}],
#   'title': '"The Calvinistic and Socinian Systems Compared as to Their Moral Tendency"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_8d8fd0e422c7': {'referenced_in': [{'topic_id': 'top_cfca4bcdf259',
#     'theologian_id': 'theo_79a75722c278',
#     'outline_id': 'out_509463607452',
#     'markdown_path': 'outlines/eschatology/millennial-views/robert-b.-strimple.md'}],
#   'title': '"The Case for Amillennialism" (various published essays and lectures)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_38c567678117': {'referenced_in': [{'topic_id': 'top_6cf266588fcf',
#     'theologian_id': 'theo_e85049ceff8c',
#     'outline_id': 'out_e7e700e2104f',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/baptism-mode-infant-vs-believers-efficacy/gregg-strawbridge.md'}],
#   'title': '"The Case for Covenantal Infant Baptism" (editor and contributor)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_d8c153049c01': {'referenced_in': [{'topic_id': 'top_5917eae5d42b',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_f07330d70f18',
#     'markdown_path': 'outlines/christology/chalcedonian-definition-and-two-natures-doctrine/herman-bavinck.md'},
#    {'topic_id': 'top_8d8955b5310f',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_f493c3222cc6',
#     'markdown_path': 'outlines/eschatology/romans-11-and-israels-future/herman-bavinck.md'},
#    {'topic_id': 'top_ce369aff319a',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_404ecf2dcc4c',
#     'markdown_path': 'outlines/pneumatology/pentecostalism-and-reformed-response/herman-bavinck.md'},
#    {'topic_id': 'top_d13293a2cece',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_18672d97bca8',
#     'markdown_path': 'outlines/anthropology-&-doctrine-of-creation/eschatological-anthropology/herman-bavinck.md'},
#    {'topic_id': 'top_d158aad0de85',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_975a979a5d96',
#     'markdown_path': 'outlines/pneumatology/spirit-and-union-with-christ/herman-bavinck.md'}],
#   'title': '"The Catholicity of Christianity and the Church"',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_c4ec0c465a3e': {'referenced_in': [{'topic_id': 'top_0a257aa5da08',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_f70f7d6b1fd8',
#     'markdown_path': 'outlines/bibliology/general-and-special-revelation/herman-bavinck.md'},
#    {'topic_id': 'top_4a04b146066a',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_eebb1caa99dc',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/rahners-rule-and-barths-reformulation/herman-bavinck.md'},
#    {'topic_id': 'top_4d8a12d40876',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_cabc7b503ed3',
#     'markdown_path': 'outlines/eschatology/new-heavens-and-new-earth/herman-bavinck.md'},
#    {'topic_id': 'top_51340b70fbc9',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_4dc03edd47f2',
#     'markdown_path': 'outlines/bibliology/analogia-entis-vs-analogia-fidei/herman-bavinck.md'},
#    {'topic_id': 'top_63d8723083d3',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_a223551ed470',
#     'markdown_path': 'outlines/eschatology/realized-vs-future-eschatology/herman-bavinck.md'},
#    {'topic_id': 'top_75286856d56e',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_a209bcbd815d',
#     'markdown_path': 'outlines/pneumatology/spiritual-gifts-and-sanctification/herman-bavinck.md'},
#    {'topic_id': 'top_893de9db2290',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_a69d7e59509b',
#     'markdown_path': 'outlines/bibliology/canon-and-tradition/herman-bavinck.md'},
#    {'topic_id': 'top_95f6db90a829',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_06594fd43a4e',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/church-government-presbyterian-polity-offices-discipline/herman-bavinck.md'},
#    {'topic_id': 'top_98b75f059a25',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_6b5c7e1997bc',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/reformation-ecclesiology/herman-bavinck.md'},
#    {'topic_id': 'top_a08c7eb01fa2',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_4462cd25d7d6',
#     'markdown_path': 'outlines/christology/christ-in-ot-and-nt/herman-bavinck.md'},
#    {'topic_id': 'top_a0bc1cbe3382',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_edbd0939de9b',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/eternal-generation-and-spiration/herman-bavinck.md'},
#    {'topic_id': 'top_a6ab38e08ca3',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_48e98ce56398',
#     'markdown_path': 'outlines/theology-proper/simplicity-aseity-immutability-impassibility/herman-bavinck.md'},
#    {'topic_id': 'top_acae6fb0ac6d',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_9eb2cfa6d669',
#     'markdown_path': 'outlines/covenant-theology/typology-and-fulfillment/herman-bavinck.md'},
#    {'topic_id': 'top_bcdbe3b27a7f',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_5102e6f8e9db',
#     'markdown_path': 'outlines/eschatology/antichrist-and-man-of-lawlessness/herman-bavinck.md'},
#    {'topic_id': 'top_c44b9de77e53',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_a0bfbabb6159',
#     'markdown_path': 'outlines/eschatology/delay-of-the-parousia/herman-bavinck.md'},
#    {'topic_id': 'top_cfca4bcdf259',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_b8ac702960eb',
#     'markdown_path': 'outlines/eschatology/millennial-views/herman-bavinck.md'},
#    {'topic_id': 'top_d31900b00a67',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_b3b02520c923',
#     'markdown_path': 'outlines/eschatology/revelation-20-and-the-millennium/herman-bavinck.md'},
#    {'topic_id': 'top_f0438f11376d',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_3b937caea2a8',
#     'markdown_path': 'outlines/doctrine-of-the-trinity/filioque-and-ecumenical-creeds/herman-bavinck.md'},
#    {'topic_id': 'top_f97189979aa0',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_998f32871c70',
#     'markdown_path': 'outlines/bibliology/accommodation-and-incarnational-analogy/herman-bavinck.md'}],
#   'title': '"The Catholicity of Christianity and the Church" (essay)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_5b115ab31c58': {'referenced_in': [{'topic_id': 'top_98b921136462',
#     'theologian_id': 'theo_aff4ec250119',
#     'outline_id': 'out_c870382ec498',
#     'markdown_path': 'outlines/ecclesiology-&-sacraments/church-and-state-relations/herman-bavinck.md'}],
#   'title': '"The Catholicity of Christianity and the Church" (in Essays on Religion, Science, and Society)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  'work_9b049d06d5a0': {'referenced_in': [{'topic_id': 'top_99edd6956d50',
#     'theologian_id': 'theo_01d6e8e3cff7',
#     'outline_id': 'out_5b75c99acc16',
#     'markdown_path': 'outlines/eschatology/individual-and-cosmic-eschatology/richard-b.-gaffin-jr..md'}],
#   'title': '"The Centrality of the Resurrection" (Westminster Theological Journal)',
#   'primary_author_theologian_id': None,
#   'is_topic_keywork': False},
#  ...}

# %%
by_theologian[list(by_theologian.keys())[5]].keys()
# Out:
# dict_keys(['outlines_by_topic_category'])

# %%
work_keys = list(by_work.keys())

# %%
for work_id, work in by_work.items():
    print(work["referenced_in"])
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 for work_id, work in by_work.items()[::-1]:
#       2     print(work["referenced_in"])
#       3     break
#
# TypeError: 'dict_items' object is not subscriptable

# %%
by_work[work_keys[-1]]
# Out:
# {'title': 'Defending Constantine',
#  'primary_author_theologian_id': 'theo_db4c242e157e',
#  'is_topic_keywork': True,
#  'authors': [{'id': 'theo_db4c242e157e',
#    'slug': 'peter-j.-leithart',
#    'full_name': 'Peter J. Leithart'}]}

# %%
by_work[work_keys[0]]
# Out:
# {'referenced_in': [{'topic_id': 'top_bcdbe3b27a7f',
#    'theologian_id': 'theo_38bdde67d604',
#    'outline_id': 'out_88289cdc8036',
#    'markdown_path': 'outlines/eschatology/antichrist-and-man-of-lawlessness/gregory-k.-beale.md'}],
#  'title': '"1–2 Thessalonians" (IVP New Testament Commentary, 2003)',
#  'primary_author_theologian_id': None,
#  'is_topic_keywork': False}

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Unify by_work.json entries:
- Ensure consistent keys for topic and outline works
- Fill primary_author_theologian_id for outline works if unique
- Always include authors[], even if empty
- Always include is_topic_keywork (bool)
"""

import json, pathlib

DATA_DIR = pathlib.Path("../data")
BY_WORK_JSON = DATA_DIR / "indices/by_work.json"

by_work = json.loads(BY_WORK_JSON.read_text(encoding="utf-8"))
changed = 0

for wid, node in by_work.items():
    # Ensure title
    node.setdefault("title", "")

    # Normalize is_topic_keywork
    node["is_topic_keywork"] = bool(node.get("is_topic_keywork"))

    # Normalize authors list
    authors = node.get("authors")
    if not isinstance(authors, list):
        node["authors"] = []

    # If primary_author_theologian_id is missing, try to infer from referenced_in
    if not node.get("primary_author_theologian_id"):
        refs = node.get("referenced_in") or []
        tids = {r.get("theologian_id") for r in refs if r.get("theologian_id")}
        if len(tids) == 1:
            node["primary_author_theologian_id"] = list(tids)[0]
            # also add to authors[] if empty
            if not node["authors"]:
                node["authors"] = [{"id": node["primary_author_theologian_id"]}]
            changed += 1

BY_WORK_JSON.write_text(json.dumps(by_work, ensure_ascii=False, indent=2), encoding="utf-8")
print(f"Normalized {len(by_work)} works, filled {changed} primary_author ids")
# Out:
# Normalized 8225 works, filled 7010 primary_author ids

# %%
#!/usr/bin/env python3
import os, json, pathlib, datetime, shutil
from flask import Flask, jsonify, request, send_from_directory
from dotenv import load_dotenv

load_dotenv()
ROOT = pathlib.Path(".").parent.resolve()
DATA_DIR = pathlib.Path(os.getenv("DATA_DIR", ROOT / "../data")).resolve()

THEO_FILE = DATA_DIR / "theologians.json"
WORK_FILE = DATA_DIR / "works.json"
AUTHORS_REGISTRY = DATA_DIR / "authors_registry.json"
OUTLINES_JSONL = DATA_DIR / "outlines.jsonl"
BY_WORK = DATA_DIR / "indices/by_work.json"
BY_TOPIC = DATA_DIR / "indices/by_topic.json"
BY_THEO = DATA_DIR / "indices/by_theologian.json"
SEARCH_INDEX = DATA_DIR / "indices/search_index.json"

app = Flask(__name__, static_folder=str(ROOT / "static"))


def _load_json(path: pathlib.Path, default=None):
    try:
        return json.loads(path.read_text(encoding="utf-8"))
    except FileNotFoundError:
        return default


def _read_jsonl(p):
    try:
        lines = p.read_text(encoding="utf-8").splitlines()
    except FileNotFoundError:
        return []
    out = []
    for line in lines:
        line = line.strip()
        if not line:
            continue
        try:
            out.append(json.loads(line))
        except Exception:
            pass
    return out


def _write_json(path: pathlib.Path, obj):
    ts = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    if path.exists():
        backups = path.parent / "backups"
        backups.mkdir(parents=True, exist_ok=True)
        shutil.copy2(path, backups / f"{path.name}.bak-{ts}")
    path.write_text(json.dumps(obj, ensure_ascii=False, indent=2), encoding="utf-8")


CACHE = {}


def _reload():
    CACHE["theologians"] = _load_json(THEO_FILE, [])
    CACHE["works"] = _load_json(WORKS_FILE, [])
    CACHE["outlines"] = _read_jsonl(OUTLINES_JSONL)
    CACHE["authors_registry"] = _load_json(AUTHORS_REGISTRY, {})
    CACHE["by_work"] = _load_json(BY_WORK_JSON, {})
    CACHE["by_topic"] = _load_json(BY_TOPIC, {})
    CACHE["by_theologian"] = _load_json(BY_THEO, {})
    CACHE["search_index"] = _load_json(SEARCH_INDEX, [])


def _load_map(all_works):
    rows = _load_json(MAP_FILE, []) or []
    m = {}
    for r in rows:
        wid = r.get("work_id");
        cid = r.get("canonical_id")
        if wid and cid:
            m[wid] = cid
    # ensure all work ids have a mapping (identity)
    for w in (all_works or []):
        wid = w.get("id")
        if wid:
            m.setdefault(wid, wid)
    # compress
    for wid in list(m.keys()):
        m[wid] = _root(m, wid)
    return m


def _save_map(m):
    rows = [{"work_id": wid, "canonical_id": cid} for wid, cid in sorted(m.items())]
    _write_json(MAP_FILE, rows)


_reload()
outlines = CACHE["outlines"]
works = CACHE["works"]
theologians = CACHE["theologians"]
authors_registry = CACHE["authors_registry"]
by_work = CACHE["by_work"]
by_topic = CACHE["by_topic"]
by_theologian = CACHE["by_theologian"]
search_index = CACHE["search_index"]



def IDT(tid):
    for t in theologians:
        if t["id"] == tid:
            return t.get("name", "")
    else:
        return ""
def TID(name):
    """Return the theologian id for a given name, or None if not found."""
    for t in theologians:
        if t.get("name") == name or t.get("full_name") == name:
            return t["id"]
    return None
check_names = {
    "Alan Spence": "Alan J. Spence",
    "Catherine McDowell": "Catherine L. McDowell",
    "David Fergusson": "David S. Fergusson",
    "Edward J. Young": "E.J. Young",
    "Gentry": "Peter J. Gentry",
    "Gordon Fee": "Gordon D. Fee",
    "Graham Cole": "Graham A. Cole",
    "Greg K. Beale": "Gregory K. Beale",
    "J.K. Beale": "Gregory K. Beale",
    "James Hamilton": "James M. Hamilton Jr.",
    "John Frame": "John M. Frame",
    "John MacArthur": "John F. MacArthur",
    "John Kilner": "John F. Kilner",
    "John Walton": "John H. Walton",
    "John Cooper": "John W. Cooper",
    "John Zizioulas": "John D. Zizioulas",
    "John Feinberg": "John S. Feinberg",
    "Joshua Farris": "Joshua R. Farris",
    "Michael Horton": "Michael S. Horton",
    "Peter Lillback": "Peter A. Lillback",
    "R. Michael Allen": "Michael Allen",
    "Richard Muller": "Richard A. Muller",
    "Richard Gaffin": "Richard B. Gaffin Jr.",
    "Scott Oliphint": "K. Scott Oliphint",
}


check_ids = {
    'theo_62f645237cbb': 'theo_c66c309571d9',
    'theo_253aff752917': 'theo_dde2bb8d741f',
    'theo_b9954d5c121e': 'theo_45caa804f8e0',
    'theo_4fee92d32985': 'theo_258a625b4ef0',
    'theo_46c70c2943c0': 'theo_3907f7b67a12',
    'theo_97952d3f743d': 'theo_6c80a418d7d3',
    'theo_440ea3109c7d': 'theo_364cc75ee079',
    'theo_c30de6e1e9d5': 'theo_38bdde67d604',
    'theo_af1da100ed05': 'theo_38bdde67d604',
    'theo_b4bc91dbb7bb': 'theo_02d402e5475a',
    'theo_a9d7b0a5f494': 'theo_ea6658b8fe68',
    'theo_eb306afbcaaa': 'theo_95d2d502c3ed',
    'theo_3744a9f4a218': 'theo_97c5607b2a3f',
    'theo_669053ae4ac4': 'theo_59a7835435c2',
    'theo_ce6917d33274': 'theo_19f8ef8dc16d',
    'theo_978af2b7052c': 'theo_c45d52affb4c',
    'theo_0a7a3b8cebf5': 'theo_e0b69ac23733',
    'theo_17f2cdad80ea': 'theo_3bbe3faed649',
    'theo_af308ef786d9': 'theo_2c429c991f77',
    'theo_fdc11111194f': 'theo_cf2f4adad47b',
    'theo_137dccd720d4': 'theo_d04d5e20087a',
    'theo_8632e4000bfa': 'theo_0a257bf889f6',
    'theo_452e8ff3c243': 'theo_01d6e8e3cff7',
    'theo_92ae76efc1c9': 'theo_36708a47db3b'
}
for o in outlines:
    tid = o.get("theologian_id")
    t_name = IDT(tid)
    if IDT(tid) in check_names:
        new_name = check_names[t_name]
        new_id = TID(new_name)


for t in theologians:
    t_name = t["name"]
    t_full_name = t["full_name"]
    if t_full_name in check_names:
        t_new_name = check_names[t_full_name]
        t_new_id = TID(t_new_name)

import re, unicodedata
def _slugify(s: str) -> str:
    s = unicodedata.normalize("NFKD", s or "")
    s = s.encode("ascii", "ignore").decode("ascii").lower()
    s = re.sub(r"[^a-z0-9]+", "-", s).strip("-")
    return re.sub(r"-{2,}", "-", s)

updated_by_work = dict()

for wid, work in by_work.items():
    deep_copy = work.copy()
    primary_tid = work.get("primary_author_theologian_id")
    new_primary_tid = check_ids.get(primary_tid, primary_tid)
    work["primary_author_theologian_id"] = new_primary_tid



    new_refs = []
    for ref in work.get("referenced_in", []):
        rt_id = ref["theologian_id"]
        new_rt_id = check_ids.get(rt_id, rt_id)

        ref["theologian_id"] = new_rt_id
        new_refs.append(ref)

        print("updated reference", rt_id, "to", new_rt_id)

    work["referenced_in"] = new_refs

    new_authors = []
    for author in work.get("authors", []):
        author_id = author.get("id")
        new_author_id = check_ids.get(author_id, author_id)
        new_author_full_name = IDT(new_author_id)
        new_slug = _slugify(new_author_full_name)

        new_authors.append({
            "id": new_author_id,
            "slug": new_slug,
            "full_name": new_author_full_name
        })
        print("updated author", author_id, "to", new_author_id, new_slug, new_author_full_name)

    work["authors"] = new_authors

    updated_by_work[wid] = work

    if work != by_work[wid]:
        print(f"Updated {wid} from {deep_copy} to {work}")
        updated_by_work[wid] = work

keyset = set()
updated_by_topic = {}
for topic_id, topic_data in by_topic.items():
    topic_theos = topic_data["theologians"]

    new_topic_theos = []
    for theo in topic_theos:
        theologian_id = theo["theologian_id"]
        if theologian_id in check_ids:
            new_id = check_ids.get(theologian_id, theologian_id)
            print(check_ids[theologian_id])
            new_theo = {
                "full_name": IDT(new_id),
                "theologian_id": new_id,
                "slug": _slugify(IDT(new_id))
            }
            new_topic_theos.append(new_theo)
        else:
            new_topic_theos.append(theo)

    new_topic_theos = new_topic_theos if new_topic_theos else [n for n in topic_theos]

    updated_by_topic[topic_id] = {k: v for k, v in by_topic.items()}
    updated_by_topic[topic_id]["theologians"] = new_topic_theos

# %%
keyset = set()
updated_by_topic = {}
for topic_id, topic_data in by_topic.items():
    topic_theos = topic_data["theologians"]

    new_topic_theos = []
    for theo in topic_theos:
        theologian_id = theo["theologian_id"]
        if theologian_id in check_ids:
            new_id = check_ids.get(theologian_id, theologian_id)
            print(check_ids[theologian_id])
            new_theo = {
                "full_name": IDT(new_id),
                "theologian_id": new_id,
                "slug": _slugify(IDT(new_id))
            }
            new_topic_theos.append(new_theo)
        else:
            new_topic_theos.append(theo)

    new_topic_theos = new_topic_theos if new_topic_theos else [n for n in topic_theos]


    updated_by_topic[topic_id] = {k:v for k, v in by_topic.items()}
    updated_by_topic[topic_id]["theologians"] = new_topic_theos

# %%
for k, v in updated_by_topic.items():
    if v != by_topic[k]:
        bt_theos = [b["theologian_id"] for b in by_topic[k]["theologians"]]
        ut_theo = [b["theologian_id"] for b in v["theologians"]]

        print(bt_theos == ut_theo)
        print(ut_theo)
        # print(by_topic[k])

        break
# Out:
# True
# ['theo_bbaf9204ff14', 'theo_fd6d1af54939', 'theo_83f0d17280ee', 'theo_0fb2dd147a7b', 'theo_991f5a107a5c', 'theo_ff69d567b651', 'theo_81db768c415a', 'theo_5ce5eb6d4e76', 'theo_4adfd8bebd91', 'theo_592b834e385e', 'theo_3fc45f8c5a0a', 'theo_1c0566e3d363', 'theo_6d606eaa0755', 'theo_aff4ec250119', 'theo_082b15f5fc01', 'theo_a1d8cf894ef6', 'theo_ea6658b8fe68', 'theo_0967b706d70a', 'theo_09edae13e8c2', 'theo_576aa8dc749e', 'theo_58387045c6b4', 'theo_4957eb6ae45c', 'theo_124906e9ce1f', 'theo_01d6e8e3cff7', 'theo_c4bd273d811a', 'theo_888da193d4d0', 'theo_de14dfbee36e', 'theo_f0740853d304', 'theo_4d5360a0b60c', 'theo_2a4f308c7e0f', 'theo_d202f60f304c', 'theo_e482a45012cc', 'theo_fdb0163ae082']

# %%
ifor wid, work in by_work.items():
    if work != updated_by_work[wid]:
        print("asdf")

# %%
updated_by_theologian = dict()
for tid, tdata in by_theologian.items():
    outlines = tdata["outlines_by_topic_category"]
    tid = check_ids.get(tid, tid)
    ndata = by_theologian.get(tid, {})
    if ndata:
        n_outlines = ndata["outlines_by_topic_category"]
        n_topic_outlines = [(category, topic) for category, topic_data in n_outlines.items() for topic in topic_data]
        for category, topic in n_topic_outlines:
            if category not in outlines:
                outlines[category] = []
            if topic not in outlines[category]:
                outlines[category].extend(topic)

    updated_by_theologian[tid] = tdata
    updated_by_theologian[tid]["outlines_by_topic_category"] = outlines

# %%
for theo in theologians:
    theo_id = theo["id"]
    if theo_id in check_ids:
        canon_id = check_ids[theo_id]
        canon_theo = [t for t in theologians if t["id"] == canon_id][0]


        for key, value in theo.items():
            if canon_theo[key] != value and key == "wts_relevance":
                print(value, canon_theo[key])

        updated_theo = {
                        "id": canon_theo.get("id", ""),
            "slug": _slugify(canon_theo.get("full_name", "")),
            "full_name": canon_theo.get("full_name", ""),
            "name": canon_theo.get("name", ""),
            "dates": max(theo.get("dates", ""), canon_theo.get("dates", "")),
            "era_category": canon_theo.get("era_category", []),
            "traditions": list(set(theo.get("traditions", []) + canon_theo.get("traditions", []))),
            "bio": canon_theo.get("bio", ""),
            "timeline": canon_theo.get("timeline", []),
            "key_work_ids": list(set(theo.get("key_work_ids", []) + canon_theo.get("key_work_ids", []))),
            "wts_relevance": max(theo.get("wts_relevance", 0), canon_theo.get("wts_relevance", 0)),
            "created_at": canon_theo.get("created_at", ""),
            "updated_at": canon_theo.get("updated_at", "")
        }


{'id': 'theo_b9515ffe8f41',
 'slug': 'anselm-of-canterbury',
 'full_name': 'Anselm of Canterbury',
 'name': 'Anselm of Canterbury',
 'dates': '1033–1109',
 'era_category': [],
 'traditions': [],
 'bio': '',
 'timeline': [],
 'key_work_ids': [],
 'wts_relevance': True,
 'created_at': '2025-08-16',
 'updated_at': '2025-08-16'}
# Out:
# True False
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[439], line 13
#       9     if canon_theo[key] != value and key == "wts_relevance":
#      10         print(value, canon_theo[key])
#      12 updated_theo = {
# ---> 13     "dates": max(canon_theo["dates"], theo["dates"], key=lambda x:len(x) if x.isInstance(x, str) else 0),
#      14 }
#
# Cell In[439], line 13, in <lambda>(x)
#       9     if canon_theo[key] != value and key == "wts_relevance":
#      10         print(value, canon_theo[key])
#      12 updated_theo = {
# ---> 13     "dates": max(canon_theo["dates"], theo["dates"], key=lambda x:len(x) if x.isInstance(x, str) else 0),
#      14 }
#
# AttributeError: 'NoneType' object has no attribute 'isInstance'
